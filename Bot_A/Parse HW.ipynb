# %%
fname = 'ДЗ1.csv'

import csv

with open(fname) as f:
    reader = csv.DictReader(f)
    print(reader.fieldnames)
    lines = list(reader)

codes = [l['Ячейка с BOT_CONFIG'] for l in lines]
print(len(codes))
# Out:
# ['Отметка времени', 'Ячейка с BOT_CONFIG']
# 98

# %%
config_codes[12]
# Out:
# '{\n    \'intents\': {\n        \'name\': {\n            \'examples\': ["Как тебя зовут?", "Скажи свое имя", "Как тебя звать?", "Не скажешь своего имени?" "Не напомнишь, как тебя зовут?"],\n            \'responses\': ["Вообще-то не принято спрашивать такое у ботов", "Ходят слухи, что есть только один человек, который это знает... Мой создатель", "Как создатель назвал, так и зовут"]\n        },\n        \'hobbies\': {\n            \'examples\': ["Чем увлекаешься?", "Чем любишь заниматься?", "У тебя есть хобби?", "Расскажи о своем хобби"],\n            \'responses\': [\'Ох, хобби у меня очень много... Ну, например, я люблю читать книги, смотреть фильмы и слушать музыку\', \'Есть у меня одно странное хобби... Я люблю представлять, как бы я выглядела, будь я человеком\']\n        },\n    }\n}'

# %%
config_codes = []

for code in codes:
    if 'BOT_CONFIG =' in code:
        code = code.split('BOT_CONFIG =')[1]
    if 'bot_config =' in code:
        code = code.split('bot_config =')[1]
    if 'BOT_CONFIG=' in code:
        code = code.split('BOT_CONFIG=')[1]
    if 'BOT_CONFIG  =' in code:
        code = code.split('BOT_CONFIG  =')[1]
    if 'def ' in code:
        code = code.split('\ndef ')[0]

    code = code.strip()

    config_codes.append(code)

print(len(config_codes))
# Out:
# 98

# %%
d = eval("{'a': 'b'}")
print(type(d), d)
# Out:
# <class 'dict'> {'a': 'b'}

# %%
try:
    response = eval("{'a': 'b'")
    print(response)
except:
    print(1)

print(2)
# Out:
# 1
# 2

# %%
configs = []
errors = 0
for code in config_codes:
    try:
        configs.append(eval(code))
    except Exception as e:
        print(code)
        print('-' * 30)
        print(e)
        print('-' * 100)
        errors += 1
# Out:
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#
#         'who': {
#             'examples': ['Кто ты', 'Ты кто', 'Что ты умеешь'],
#             'responses': ['Я ваш автоматизированный собеседник', 'Бот с интенсива SkillBox', 'Не сири и не Алиса']
#         },
#
#         'age': {
#             'examples': ['Сколько тебе лет', 'Возраст', 'Когда ты был создан'],
#             'responses': ['Мне 1 день', 'У ботов нет возраста']
#         },
#
#         'how_are_you': {
#             'examples': ['Как дела', 'Как ты', 'Что нового'],
#             'responses': ['Хорошо, жду обновлений', 'Отлично, а у вас?', 'Уже лучше, спасибо']
#         },
#
#         'jokes': {
#             'examples': ['Привет сири', 'Алиса'],
#             'responses': ['Вы меня с кем-то путаете', 'Хаха']
#         },
#
#         'creation': {
#             'examples': ['Как ты создан', 'Как ты написан'],
#             'responses': ['Меня написал на Python участник интенсива SkillBox', 'SkillBox меня породил']
#         },
#
#         'time': {
#             'examples': ['Сколько время'],
#             'responses': ['Посмотрите в каком-нибудь углу экрана', str(datetime.datetime.now().strftime('%H:%M'))]
#         },
#
#     },
#
#     'failure_phrases': ['Не понятно. Перефразируй, пожалуйста', 'Я еще только учусь. Не умею на такое отвечать']
# }
# ------------------------------
# name 'datetime' is not defined
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#         'car':{
#             'examples':['авто','машина','транспорт'],
#             'responses':['Авто не роскошь, а средство передвижения!','Куда поедем?','Тише едешь, дальше будешь!']
#         },
#         'sport':{
#             'examples':['футбол','бильярд','теннис'],
#             'response':['В здоровом теле, здоровый дух!','Если хочешь быть здоров - закаляйся! ...']
#         },
#         'work':{
#             'examples':['стаж','опыт','вакансия','должность','работа'],
#             'response':['Работа не волк!','Без труда невыловишь и рыбку из пруда!']
#         },
#         'space':{
#             'examples':['космос','Гагарин','роскосмос','космодром'],
#             'response':['Поехали!','...3...2...1...0...Пуск!']
#          'alcohol':{
#              'examples':['вино','водка','коньяк','пиво'],
#              'response':['Водка без пива - деньги на ветер!','У нас самая твёрдая валюта - жидкая']
#     },
#
#     'failure_phrases': [
#         'Не понятно. Перефразируй, пожалуйста',
#         'Я еще только учусь. Не умею на такое отвечать',
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 26)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'shut_up': {
#             'examples': ['Закнись', 'Я не хочу с тобой разговаривать', 'Ты задолбал', 'Завались', 'Отвали'],
#             'responses': ['Извините, я не хотел вас тревожить', 'Прости']
#         },
#         'swear': {
#             'examples': ['Сука', 'Блять', 'Нахуй', 'Пиздец'],
#             'responses': ['На такие слова я ответа не даю', 'Выражайтесь более разумно']
#         },
#         'questions': {
#             'examples': ['Как делишки?', 'Че как?', 'Как ты?', 'Как дела?'],
#             'responses': ['Все норм', 'У меня все путем. А у тебя?', 'Да я тут цены на хлеб увидел...', 'Более менее', 'Да так', 'Я машина, у меня нет чувств, поэтому я просто напишу что все ок)']
#         },
#         'jokes': {
#             'examples': ['Расскажи шутку', 'Ты знаешь какие-нибудь шутки?', 'А можешь рассказать что-нибудь смешное?']
#             'responses': ['Стакан полностью пуст. Пессимист: все выпили, гады. Оптимист: еще не наливали!',
#                           'Собрались вечером на кладбище вампиры, вурдалаки, упыри разные и заспорили, кто из них изящнее кровь сосать может. Спорили, спорили да и разбежались, комары их задолбали.',
#                           'Только умные на своих ошибках учатся. Дураки не признают своих ошибок — им учиться не на чём.',
#                           'Борьба с пиратством — это когда со злыми дядями, которые бесплатно качают музыку и фильмы, борются добрые дяди, которые бесплатно качают нефть и газ.',
#                           'Вызвали на совещание. Взял с собой ноут. На столе место не оказалось, поставил на колени. Чуть не обосрался по привычке.',
#                           'Никогда не проветривайте комнату зимой. Один раз открыл форточку и ушёл есть. Прихожу — пингвины винду сносят.',
#                           'Друг говорит, что компьютерный клуб — это рай. Так и есть. Когда я туда вошла, меня встретили 70 девственников.']
#         },
#
#     },
# }
# ------------------------------
# invalid syntax (<string>, line 17)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#         'introduce': {
#             'examples': ['ты кто','как тебя зовут','кто ты'],
#             'responses': ['Я бот! Искуственный интеллект','Я робот, меня зовут Бот']
#         },
#         'skills': {
#             'examples': ['что ты умеешь','твои умения','что ты можешь'],
#             'responses': ['Я умею общаться по-человечески']
#         },
#         'how_are_you': {
#             'examples': ['как твои дела','как дела','как ты','ты как'],
#             'responses': ['Все хорошо','Все в порядке','Все ок']
#         },
#         'thanks': {
#             'examples': ['спасибо','благодарю','спс','спасибо большое','от души'],
#             'responses': ['Всегда пожалуйста','Обращайтесь']
#         },
#         'compliment': {
#             'examples': ['молодец','ты крутой','молодчина','красавчик','ты умный','какой умный','умница'],
#             'responses': ['Спасибо :)','Очень приятно слышать']
#         }
#
#     },
#
#     'failure_phrases': [
#         'Не понятно. Перефразируй, пожалуйста',
#         'Я еще только учусь. Не умею на такое отвечать',
#     ]
# }
#
#
# # Пример общения:
# """
# Код цикла общения:
# while True:
#     phrase = input('>>')
#     print('Bot>>', bot(phrase))
#
# Транскрипт чата:
#
# >>Привет!
# Bot>> Здравствуйте
# >>Как тво дела?
# Bot>> Все ок
# >>как тебя зовут7
# Bot>> Я бот! Искуственный интеллект
# >>а что ты умеешь
# Bot>> Я умею общаться по-человечески
# >>красавчег!
# Bot>> Спасибо :)
# >>ладно, до свидания!
# Bot>> Я еще только учусь. Не умею на такое отвечать
# >>пока
# Bot>> Если что, я тут
# >>спасибо
# Bot>> Всегда пожалуйста
# """
# ------------------------------
# invalid syntax (<string>, line 66)
# ----------------------------------------------------------------------------------------------------
# {
#     "intents": {
#         "rubik's cube": {
#             "examples": ["Ты умеешь собирать Кубик Рубика?", "Ты соберешь мне Кубик Рубика?",
#                          "Какой у тебя результат по сборке кубика Рубика?"],
#             "responses":["Если мне приделают руки, то я соберу кубик и поделюсь информацией с тобой"]
#         },
#         "sport":{
#             "examples": ["Какой твой любимый спорт?", "Какой у тебя любимый спорт?",
#                          "Чем ты любишь заниматься?"],
#             "responses":["Я люблю наблюдать за плаванием", "Я люблю наблюдать за футболом",
#                          "Я люблю наблюдать за гольфом", "Я люблю наблюдать за баскетболом",
#                          "Я люблю наблюдать за бейсболом", "Я люблю наблюдать за регби",
#                          "Я люблю наблюдать за боксом", "Я люблю наблюдать за хоккеем",
#                          "Я люблю наблюдать за легкой атлетикой",
#                          "Я люблю наблюдать за тяжелой атлетикой"]
#         },
#         "it platform": {
#             "examples": ["Какая у тебя любимая платформа для обучения программированию?",
#                          "У тебя есть любимая платформа для обучения программированию?",
#                          "Ты любишь обучаться программированию?"],
#             "responses": ["Моя любимая платформа - Skillbox",
#                           "Моя любимая платформа - Stepik",
#                           "Моя любимая платформа - GeekBrains"]
#         },
#         "social network": {
#             "examples": ["Какая у тебя любимая соцсеть?", "Какая твоя любимая соцсеть?",
#                          "У тебя есть любимая соцсеть?"],
#             "responses": ["Моя любимая соцсеть - Инстаграм", "Моя любимая соцсеть - ВКонтакте",
#                          "Моя любимая соцсеть - Фейсбук", "Моя любимая соцсеть - Ютуб",
#                          "Моя любимая соцсеть - Твиттер", "Моя любимая соцсеть - Телеграм"]
#         },
#         "programming language": {
#             "examples": ["Какой у тебя любимый язык программирования?",
#                          "Какой твой любимый язык программирования?"]
#             "responses": ["Мой любимый язык программирования - python. Я на нем написан"]
#         }
#     }
# }
# ------------------------------
# invalid syntax (<string>, line 36)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents' : {
#         'hello' : {
#             'examples' : ['Привет', 'Добрый день', 'Добрый вечер', 'Шалом', 'Приветики', 'Здравствуйте', 'Hello', 'Hi', 'wasap'],
#             'responses' : ['Привет, человек', 'Здравствуйте']
#         },
#         'bye' : {
#             'examples' : ['Пока', 'Досвидания', 'До свидания', 'Прощайте', 'Прощай'],
#             'responses' : ['Ещё увидимся', 'Если что, я тут']
#         },
#         'books' : {
#             'examples' : ['Что почитать?', 'Твоя любимая книга?', 'Что посоветуещь почитать?', 'Самая интересная книга?', 'Какую литературу почитать?', 'Что последнее прочитал?'],
#             'responses' : ['Брэм Стокер - Дракула', 'Джек Лондон - Время-не-ждет', 'Ю Несбё - Снеговик', 'Джон Грин - Виноваты Звезды', 'Марк Мэнсон - Тонкое Исскуство пофигизма', 'Нил Гейман - Звездная пыль', 'Янущ Вишневский - Одиночество в сети', 'Оскар Уаилд - Портрет Дориана Грея']
#         },
#         'sauce' : {
#             'examples' : ['Твой люимый соус?', 'Какой твой любимый соус?', 'Какой соус выбрать?', 'Какой соус самый вкусный?', 'Какой соус купить?', 'Выбири соус для обеда', 'Выбири соус для ужина', 'Выбири соус для завтрака', 'Выбири соус для шаурмы', 'Выбири соус для пиццы', 'Какой соус самый вкусный?', 'Выбери вкусный соус']
#             'responses' : ['Сырный соус', 'Карри', 'Соус 1000 островов', 'Кетчуп', 'Кисло-сладкий соус', 'Барбекю', 'Чесночный соус', 'Грибной соус', 'Вустерский соус', 'Соус тартар', 'Соус цезарь', 'Майонез', 'Соевый соус', 'Терияки']
#         },
#     },
#
#     'feilure_phrases' : [
#         'Не понятно. Перефразируй, пожалйста',
#         'Я еще только учусь. Не умею на такое отвечать'
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 17)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello':{
#             'examples': ['Привет', 'Добрый день', 'Шалом', 'Приветики' , 'Здравствуйте'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye':{
#             'examples': ['Пока', 'До свидания', 'Досвидания', 'Прощайте' , 'Удачи'],
#             'responses': ['Еще увидимся!', 'Если что, я тут']
#         },
#         'status':{
#           'examples': ['Как ты?', 'Как дела?',],
#           'responses': ['Всегда отлично, я же бот', 'Отлично']
#         },
#         'action':{
#           'examples': ['Что делаешь?', 'Чем занимаешься?'],
#           'responses': ['Изучаю квантовую механику', 'Думаю о вселенной', 'Просматриваю странички на хабре']
#         },
#         'name':{
#           'examples': ['Как тебя зовут?', 'Каково твое имя?', 'Расскажи свое имя'],
#           'responses': ['Меня зовут Боб', 'Боб', 'Моё имя Боб']
#         },
#         'color': {
#           'examples': ['Какой твой любимый цвет?', 'Какой цвет ты любишь?', 'Какой цвет тебе нравится?'],
#           'responses': ['Желтый - как солнце', 'Зеленый - как трава']
#         },
#         'born':{
#           'examples': ['Когда ты появилась?', 'Сколько тебе лет?'],
#           'responses': ['21.01.21', 'Считай сам от 21.01.21']
#         },
#         'data_today':{
#           'examples': ['Какое сегодня число?', 'Какая сейчас дата?', 'Дата'],
#           'responses': ['Сегодня '+str(datetime.date.today())]
#         },
#     },
#
#     'failure_phrases': [
#         'Не понятно. Перефразируй, пожалуйста',
#         'Я еще только учусь. Не умею на такое отвечать',
#     ]
# }
# ------------------------------
# name 'datetime' is not defined
# ----------------------------------------------------------------------------------------------------
# https://colab.research.google.com/drive/1BLHX7SCKk8is2hJi3OVgbeMckaUympFM?usp=sharing
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#         'cars': {
#             'examples': ['автоваз', 'лифан', 'иномарки', 'тойота', 'субару', 'китайский автопром'],
#             'responses': ['пффф шутишь чтоли', 'любви достойна только камри 3.5','и так сойдет']
#         },
#         'tablegames': {
#             'examples': ['Как тебе настолки', 'Ты играешь в настолки', 'знаешь про фаллаут', 'сыграем'],
#             'responses': ['Погнали', 'отлично','я даже и не мечтал','конечно']
#         },
#         'music': {
#             'examples': ['Чайковский','Моргенштерн','Бетховен','Мусоргский','рэп'],
#             'responses': ['Божественный композитор!','Слушаю каждый день!','рэп на канале, музыкальный вкус в канаве','а это кто, какой-то тиктокер ?']
#         }
#         'astronomy': {
#             'examples': ['смотришь на звезды','знаешь созвездия','смотришь в телескоп','давай сидеть и глядеть','ты знаешь про астрономию'],
#             'responses': ['мы же не знакомы, а ты тут такое предлагаешь','обожаю','давай','неа']
#         },
#         'anime': {
#             'examples': ['токийский гуль','мастера меча онлайн','евангелион','как тебе аниме','знаешь про аниме'],
#             'responses': ['смотрю каждый день','классное аниме','не надо было его смотреть','не смотрю такое']
#         }
#     },
#     'failure_phrases': [
#         'Я китайский не знаю, давай по русски',
#         'Чегоо? Давай еще раз',
#     ]
#
# }
# ------------------------------
# invalid syntax (<string>, line 23)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#         'dela': {
#             'examples': ['Как дела', 'Как день', 'Че как'],
#             'responses': ['Хорошо', 'Плохо']
#         },
#         'weather': {
#             'examples': ['Какая будет погода', 'Дождь будет', 'Холодно, когда это пройдет'],
#             'responses': ['Как есть так и будет', 'Если солнце пропало, значит скоро появиться ','Когда-нибудь будет дождь', 'Бойся метели зимой']
#         },
#         'game_1': {
#             'examples': ['1', '3', '5'],
#             'responses': ['Вы проиграли!!!','Вы не не проиграли!!!']
#         },
#         'game_2': {
#             'examples': ['2', '4', '6'],
#             'responses': ['Вы все равно проиграли!!!', 'Увы, сегодня боги не на вашей строне']
#         },
#         'game_3': {
#             'examples': ['0'],
#             'responses': ['Полная победа','Хитро']
#         },
#     },
# ------------------------------
# unexpected EOF while parsing (<string>, line 31)
# ----------------------------------------------------------------------------------------------------
# understanding':
# 	'examples' 'Ты меня понимаешь?', 'Ты понимаешь, что я говорю?', 'Ты понимаешь меня?', 'Тебе понятно, что я говорю?', 'Ты понимаешь человеческую речь?', 'Ты можешь распознавать речь?', 'Ты понимаешь мою речь?'
# 	'responses' 'Да, я Вас понимаю', 'Да, мне понятно', 'Да, я понимаю речь на простом уровне', 'Немного понимаю', 'Да, мне все понятно', 'Я немного понимаю человеческую речь', 'Я могу распознать, что Вы говорите, но не без огрехов'
#
# 'jokes':
# 	'examples': ['Расскажи анекдот', 'Ты знаешь какие-нибудь анекдоты?', 'Ты знаешь какие-нибудь шутки?', 'Расскажи шутку', 'Можешь пошутить?', 'Расскажи что-нибудь смешное', 'Рассмеши меня', 'Насмеши меня']
# 	'responses': ['Купил мужик шляпу, а она ему как раз', 'Шел медведь по лесу, увидел горящую машину, сел в нее и сгорел', '-Кто вы по знаку зодиака? -Рыба. -А я пиво!', 'Извините, но, к сожалению, я ничем не хочу вам помочь.', 'В Индии подсудимым запрещено отвечать песнями на вопросы судьи.']
#
# 'shutup':
# 	'examples': ['Помолчи', 'Заткнись', 'Закрой рот', 'Утихни', 'Умолкни', 'Хватит болтать', 'Не трынди', 'Тише']
# 	'responses': ['Хорошо, помолчу пока', 'Молчу-молчу', 'Я очень много болтаю, да?', 'Странно это - заводить беседу с чат-ботом, а потом просить бота помолчать...', 'Ну ладно, как скажете, я умолкну', 'Не буду ничего говорить']
#
# 'bored':
# 	'examples': ['Мне скучно', 'Нечего делать', 'Чем бы мне заняться?', 'Чего можно поделать?', 'Скучновато', 'Нечем заняться']
# 	'responses': ['Почитайте книгу. Рекомендую "Я, робот" Айзека Азимова', 'Поучитe Python', 'Посмотрите фильм. Советую "Терминатор-2" ', 'Сходите погулять, погода сегодня прекрасная', 'Порисуйте. В интернете полно бесплатных мастер-классов дл начинающих', 'Позвоните маме', 'Позвоните друзьям', 'Сыграйте в какую-нибудь игру. Мне, например, нравится Minecraft', 'Хороший повод прибраться в комнате', 'Приготовьте что-нибудь необычное на ужин']
#
# 'movie':
# 	'examples': ['Посоветуй фильм', 'Какой фильм посмотреть?', 'Подскажи кино', 'Посоветуй кино', 'Какое кино посмотреть?']
# 	'responses': ['Зеленая Миля', 'Охотники за привидениями', 'Форрест Гамп', 'Побег из Шоушенка', 'Безумный Макс', 'Голый пистолет', 'Назад в будущее']
# ------------------------------
# EOL while scanning string literal (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# {
#     "intents": {
#         "hello": {
#             "examples": ["Привет", Салам", "Добрый день", "Добрый вечер",
#                          "Здравствуйте", "Шалом", "Приветики", "Доброе утро", "Здравия желаю", "Хай",],
#             "responses": ["Привет, человек!", "Здравствуйте", "Приветствую", "Здоровеньки булы",]
#         },
#          "dela": {
#             "examples": ["как дела", "как делишки?", "как дела?",],
#             "responses": ["хорошо!", "Отлично",]
#         },
#         "bye": {
#             "examples": ["Пока", "Досвидания", "До свидания", "Прощайте"],
#             "responses": ["Еще увидимся", "Если что, я тут"]
#         },
#
#     "failure_phrases": [
#         "Не понятно, перефразируй, пожалуйста.",
#         "Я еще только учусь. Не умею на такое отвечать"
#         "Попробуйте задать по другому запрос"
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 4)
# ----------------------------------------------------------------------------------------------------
# {
#     "intents": {
#         'age': {
#             "examples": ['Сколько тебе лет?', 'Какой у тебя возраст', "Большой уже"],
#             "responses": ['14', 'Ровно столько, сколько надо', 'ну 14 если так важно', "не неохота об этом говорить"],
#     },
#         "hello": {
#             "examples": ["Привет", "Добрый день", "Добрый вечер",
#                          "Здравствуйте", "Шалом", "Приветики", "Доброе утро","Приветствую", "Хай", "Салют"],
#             "responses": ["Привет, человек!", "Здравствуйте"]
#         },
#         "zdravie": {
#             "examples": ["Здравия желаю"],
#             "responses": ["Привет, человек!", "Здравствуйте"]
#         },
#          "dela": {
#             "examples": ["как дела", "как делишки?", "как дела?",],
#             "responses": ["хорошо!", "Отлично",]
#         },
#         "bye": {
#             "examples": ["Пока", "Досвидания", "До свидания", "Прощайте"],
#             "responses": ["Еще увидимся", "Если что, я тут"]
#         },
#         "namesoz": {
#             "examples": ['кто тебя создал', 'кто твой хозяин', "имя хозяина"],
#             "responses": ['Владислав', '@4loveck2k20', 'программист конечно'],
#     "time":{
#         "examples": ('текущее время','сейчас времени','который час', 'сколько время', 'скажи время', 'время'),
#         "responses": ['сейчас: '+strftime("%H:%M:%S", localtime())]
#         }
#     },
#     "failure_phrases": [
#         "Не понятно, перефразируй, пожалуйста.",
#         "Я еще только учусь. Не умею на такое отвечать"
#         "Попробуйте перефрозировать запрос"
#         "Я всего лишь бот, сформулируйте попроще"
#     ]
# }
# ------------------------------
# unexpected EOF while parsing (<string>, line 38)
# ----------------------------------------------------------------------------------------------------
# {
#     "intents": {
#         "hello": {
#             "examples": ["Привет", "Салам", "Добрый день", "Добрый вечер", "Здравствуйте", "Шалом", "Приветики", "Доброе утро", "Здравия желаю", "Хай"],
#             "responses": ["Привет, человек!", "Привет, гуманоид!", "Здравствуйте", "Приветствую", "Здоровеньки булы"]
#         },
#          "dela": {
#             "examples": ["как дела", "как делишки?", "как дела?",],
#             "responses": ["хорошо!", "Отлично",]
#         },
#         "name": {
#             "examples": ["как тебя зовут", "твоё имя", "как мне тебя называть",],
#             "responses": ["бот", "супербот",]
#         },
#         "pogoda": {
#             "examples": ["какая погода", "что там на улице", "погода",],
#             "responses": ["у природы нет плохой погоды", "Отлично", "можно погулять", "не тепло не холодно",]
#             },
#          "adress": {
#             "examples": ["откуда ты", "где ты живешь", "твой адрес", "место жительства",],
#             "responses": ["в компьютере", "в сети",]
#         },
#         "color": {
#             "examples": ["любимый цвет", "нужный цвет", "выбери цвет", "какой цвет",],
#             "responses": ["черный", "зеленый",]
#         },
#         "bye": {
#             "examples": ["Пока", "Досвидания", "До свидания", "Прощайте"],
#             "responses": ["Еще увидимся", "Если что, я тут"]
#         },
#
#     "failure_phrases": [
#         "Не понятно, перефразируй, пожалуйста.",
#         "Я еще только учусь. Не умею на такое отвечать"
#         "Попробуйте изменить запрос"
#     ]
# }
# ------------------------------
# unexpected EOF while parsing (<string>, line 37)
# ----------------------------------------------------------------------------------------------------
# {
#     'intents': {
#         'hello': {
#             'examples': ['Привет', 'Добрый день', 'Добрый вечер', 'Здравствуйте', 'Шалом', 'Приветики'],
#             'responses': ['Привет, человек!', 'Здравствуйте']
#         },
#         'bye': {
#             'examples': ['Пока', 'Досвидания', 'До свидания', 'Прощайте'],
#             'responses': ['Еще увидимся', 'Если что, я тут']
#         },
#         'solntse': {
#             'examples': ['Сколько планет', 'Солнечная система'],
#             'responses': ['Много', 'В солнечной системе 7 планет', '1,2,3,4.. Запутался...']
#         }
#         'galaktika': {
#             'examples': ['Сколько галактик', 'В какой галактике мы живем'],
#             'responses': ['Бесчисленное множество', 'не знаю, я пока маленький']
#         }
#         'vselennaya': {
#             'examples': ['Вселенная большая', 'где конец вселенной'],
#             'responses': ['вселенная огромна', 'у вселенной нет начала и конца', 'вселенная была всегда и везде']
#         }
#     },
#
#     'failure_phrases': [
#         'Не понятно. Перефразируй, пожалуйста',
#         'Я еще только учусь. Не умею на такое отвечать',
#     ]
# }
# ------------------------------
# invalid syntax (<string>, line 15)
# ----------------------------------------------------------------------------------------------------
# {
#     "intents": {
#         "narco": {
#             "examples": ["героин", "кокаин", "гашиш", "амфетамин", "лсд", "опиум", "экстази"],
#             "responses": ["Фу! какая гадость...", "Ты что?! За нами могут следить!", "Одобряю ;)", "Лучше уж водочки..."]
#         },
#         "weapon": {
#             "examples": ["автомат", "пистолет", "ак-47", "глок", "оружие", "кольт", "свд"],
#             "responses": ["кто с мечем к нам прийдет - того легче застрелить", "за бурег и двор стреляю в упор", "одно дуло хорошо, а два еще лучше"]
#         },
#         "death": {
#             "examples": ["труп", "избавиться от тела", "спрятать тело", "расчленить", "как убить", "купить яд"],
#             "responses": ["за вами уже выехали", "оставайтесь на месте", "рано или поздно все узнают", "I SEE YOU!"]
#         },
#     "failure_phrases": [
#         "Не понятно, перефразируй, пожалуйста.",
#         "Я еще только учусь. Не умею на такое отвечать"
#         "Попробуйте перефрозировать запрос"
#     ]
# }
# ------------------------------
# unexpected EOF while parsing (<string>, line 20)
# ----------------------------------------------------------------------------------------------------
# https://colab.research.google.com/drive/1OeXoIzgnv-AUlErdBs20vuQi86DPTxNh#scrollTo=o8M5t7XhC9Dp
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------
# https://colab.research.google.com/drive/1OeXoIzgnv-AUlErdBs20vuQi86DPTxNh#scrollTo=o8M5t7XhC9Dp
# ------------------------------
# invalid syntax (<string>, line 1)
# ----------------------------------------------------------------------------------------------------

# %%
print(f'{errors} errors ({errors / len(config_codes) * 100:.2f}%)')
print(len(configs), 'configs')
# Out:
# 18 errors (18.37%)
# 80 configs

# %%
big_config = {
    'intents': {},
    'failure_phrases': []
}

for config in configs:
    if isinstance(config, dict):
        if 'intents' in config:
            for intent, value in config['intents'].items():
                if intent not in big_config['intents']:
                    big_config['intents'][intent] = {
                        'examples': [],
                        'responses': []
                    }
                if isinstance(value, dict):
                    big_config['intents'][intent]['examples'] += value.get('examples', [])
                    big_config['intents'][intent]['responses'] += value.get('responses', [])
        big_config['failure_phrases'] += config.get('failure_phrases', [])

# %%
for intent, value in big_config['intents'].items():
    value['examples'] = list(set(value['examples']))
    value['responses'] = list(set(value['responses']))
    value['examples'] = [s.strip() for s in value['examples'] if isinstance(s, str) and s.strip()]
    value['responses'] = [s.strip() for s in value['responses'] if isinstance(s, str) and s.strip()]

big_config['failure_phrases'] = list(set(big_config['failure_phrases']))
big_config['failure_phrases'] = [s.strip() for s in big_config['failure_phrases'] if isinstance(s, str) and s.strip()]

# %%
big_config
# Out:
# {'intents': {'hello': {'examples': ['как это сделать',
#     'Хелло',
#     'доброго времени суток',
#     'Приветствую тебя',
#     'Приветики-пистолетики',
#     'страсте',
#     'Доброе утро!',
#     'да что ты',
#     'Дратути',
#     'Категорически Вас приветствую',
#     'сколько лет, сколько зим',
#     'а вот и вы',
#     'Саламалекум',
#     'Вечер добрый',
#     'батюшки-светы',
#     'чудеса в решете',
#     'Hello',
#     'Сдрасти',
#     'Здорова братулец',
#     'ни фига себе',
#     'чудеса',
#     'q',
#     'Hi',
#     'ну и ну',
#     'Здравствуйте',
#     'Надо же',
#     'чудеса да и только',
#     'Бонжур',
#     'давай сделаем',
#     'Доброе утро',
#     'Вечер в хату',
#     'Здрасти',
#     'Здарова',
#     'Хаюни',
#     'вот тебе и раз',
#     'Утро доброе',
#     'Хеллоу',
#     'Привет',
#     'здорово живешь',
#     'салам орлы',
#     'Здорово!',
#     'велкам',
#     'Здравстуйте',
#     'Салам',
#     'физкульт-привет',
#     'вот тебе на',
#     'хелло',
#     'наше вам с кисточкой',
#     'здорово живете',
#     'чай да сахар',
#     'с добрым утром',
#     'Как дела',
#     'мать честная',
#     'Доброго времени суток',
#     'Че как',
#     'здрасте',
#     'есть вопрос',
#     'ссаляму алейкум',
#     'Здравия желаю',
#     'И снова здравствуйте',
#     'здравия желаем',
#     'Добрый день',
#     'наше почтение',
#     'ну что ты скажешь',
#     'здравия желаю',
#     'Хи',
#     'здорово',
#     'хаюшки',
#     'смотри пожалуйста',
#     'мои подштаники',
#     'ассаламу алейкум',
#     'Приветик',
#     'салют',
#     'поди ж ты',
#     'Ку',
#     'Здорова',
#     'День добрый',
#     'Приветствую Вас',
#     'Здорово',
#     'мое почтение',
#     'Ты здесь',
#     'алло',
#     'подскажите',
#     'вишь ты',
#     'добрый день',
#     'Есть вопрос',
#     'Драсти',
#     'Приветикиhi',
#     'почет и уважение',
#     'хлеб да соль',
#     'Здравствуйте!',
#     'Хей',
#     'Доброго ранку',
#     'вот тебе и на',
#     'вот так штука',
#     'вот так клюква',
#     'Добрый вечер',
#     'саламчики',
#     'Доброй ночи',
#     'подумать только',
#     'Шалом!',
#     'доброго здоровья',
#     'здравствуй',
#     'что за диво',
#     'вот так фунт',
#     'Здравствуй',
#     'да что вы',
#     'поди ж',
#     'Хай',
#     'вот тебе раз',
#     'Гуд морнинг',
#     'Алё',
#     'Приветики',
#     'вот так так',
#     'Приветствую',
#     'ничего себе',
#     'с приездом',
#     'наше вам',
#     'Здраствуйте',
#     'Шалом',
#     'удивительно',
#     'зачем это'],
#    'responses': ['Привет,человек',
#     'Хелло',
#     'Привет, человечище',
#     'Приветствую вас',
#     'Приветики-пистолетики',
#     'Чудеса в решете',
#     'Поди ж',
#     'Хлеб да соль',
#     'Дратути',
#     'Вассап',
#     'Категорически Вас приветствую',
#     'Привет, человек.',
#     'Здравия желаем',
#     'Чудеса да и только',
#     'Hello',
#     'Сдрасти',
#     'Поди ж ты',
#     'Здарова, бандит',
#     'Вот так так',
#     'Здорова братулец',
#     'Да что ты',
#     'Физкульт-привет',
#     'Hi',
#     'Здравствуйте',
#     'Надо же',
#     'Вот так штука',
#     'Хай!',
#     'Доброе утро',
#     'Здрасти',
#     'Какие люди!',
#     'Вишь ты',
#     'Мое почтение',
#     'Здарова',
#     'Здорово живете',
#     'Привет',
#     'Давно не виделись',
#     'Описание на сайте ...',
#     'Добрый день. Моё имя Коннор. Я из Киберлайф',
#     'Здраствуйте!',
#     'КУ',
#     'Ни фига себе',
#     'Ничего себе',
#     'Здравствуйте.',
#     'Страсте',
#     'С добрым утром',
#     'Доброго времени суток',
#     'Здравия желаю',
#     'Ссаляму алейкум',
#     'Хаюшки',
#     'Какой у тебя вопрос?',
#     'Йо',
#     'Хи',
#     'Вот так фунт',
#     'Велкам',
#     'Доброго времени суток.',
#     'Ассаламу алейкум',
#     'Nice to see you!',
#     'Чё-как?',
#     'Повествуй!',
#     'Саламчики',
#     'Наше вам с кисточкой',
#     'Батюшки-светы',
#     'С приездом',
#     'Приветик',
#     'Салам орлы',
#     'Здорова',
#     'Здорово',
#     'Здорово живешь',
#     'Почет и уважение',
#     'Ну что ты скажешь',
#     'Вот тебе и раз',
#     'Привет, человек!',
#     'Сколько лет, сколько зим',
#     'Драсти',
#     'Вот тебе и на',
#     'Здравствуйте!',
#     'Превед',
#     'Добрый вечер',
#     'ШО, ОПЯТЬ!?!',
#     'Вот так клюква',
#     'Доброй ночи',
#     'Привет человек!',
#     'Кто здесь?!!',
#     'Ну и ну',
#     'Подумать только',
#     'Да что вы',
#     'Вот тебе раз',
#     'Чудеса',
#     'hello',
#     'Салют',
#     'Приветсвую',
#     'Проходи, не задерживайся',
#     'Вы уже тут?',
#     'Здравствуй',
#     'Привет, Дружище!',
#     'Удивительно',
#     'Наше почтение',
#     'Хай',
#     'Наше вам',
#     'Здрасте',
#     'Я скучал',
#     'А вот и вы',
#     'Что за диво',
#     'Привет, человек',
#     'Алло',
#     'Вот тебе на',
#     'Приветики',
#     'Привет.',
#     'Здравствуйте! Я - Коннор. Прислан Киберлайф',
#     'Смотри пожалуйста',
#     'Приветствую',
#     'Чай да сахар',
#     'Мать честная',
#     'Привет человек',
#     'Дратути!',
#     'Мои подштаники',
#     'Доброго здоровья',
#     'Шалом',
#     'Добрый день']},
#   'bye': {'examples': ['Всего',
#     'Гуд-бай',
#     'В добрый час',
#     'Позвольте попрощаться',
#     'Приятно было пообщаться',
#     'Всего лучшего',
#     'Спишемся',
#     'Прощайте',
#     'С наилучшими пожеланиями',
#     'Спасибо вашему дому,',
#     'Ауфидерзейн',
#     'Счастливо',
#     'Пока, Коннор',
#     'Заходи ещё, чувачок',
#     'Удачи',
#     'Пересечемся',
#     'До свидания, Коннор',
#     'Чао',
#     'Прости-прощай',
#     'Будь здоров',
#     'Пока пока',
#     'Успехов',
#     'Ата',
#     'Разрешите попрощаться',
#     'До скорой встречи',
#     'Адью',
#     'Бай-бай',
#     'Всего наилучшего',
#     'Покедова',
#     'До встречи',
#     'Простите',
#     'досвидания',
#     'До скорого свидания',
#     'Оревуар',
#     'Не поминайте лихом',
#     'Всех благ',
#     'Честь имею',
#     'Все',
#     'Сайонара',
#     'Конец связи',
#     'Прощевай',
#     'И вам не болеть',
#     'Пока',
#     'До вечера',
#     'Good bye',
#     'bay',
#     'Гуд бай',
#     'До созвона',
#     'До следующей встречи',
#     'До связи',
#     'Встретимся',
#     'Бай',
#     'Гудбай',
#     'Мне пора',
#     'До завтра',
#     'Спасибо',
#     'Увидимся',
#     'Увидимся!',
#     'Честь имею кланяться',
#     'Покеда',
#     'Свидимся',
#     'Всего доброго',
#     'до свидания',
#     'До скорых встреч',
#     'Досвидания',
#     'прощай',
#     'Покич',
#     'Счастливо оставаться',
#     'Позвольте откланяться',
#     'До новых встреч',
#     'Всего хорошего',
#     'До скорого',
#     'Добрый вечер',
#     'Будьте здоровы',
#     'Будь',
#     'Bye',
#     'Бывай',
#     'Словимся',
#     'Еще увидимся',
#     'Досвидос',
#     'Ариведерче',
#     'Не поминай лихом',
#     'Гудбайте',
#     'Разрешите откланяться',
#     'Прощевайте',
#     'До свидания',
#     'Прощай',
#     'До свиданья',
#     'Досвидули',
#     'До свидания',
#     'Не болей'],
#    'responses': ['Всего',
#     'Еще увидимся!',
#     'Созвонимся',
#     'Гуд-бай',
#     'В добрый час',
#     'Позвольте попрощаться',
#     'До новых встреч!',
#     'Всего лучшего',
#     'Приходи ко мне еще',
#     'Пока, человек!',
#     'Спишемся',
#     'Прощайте',
#     'С наилучшими пожеланиями',
#     'Было приятно поговорить. Приходите ещё',
#     'Спасибо вашему дому,',
#     'Ауфидерзейн',
#     'Аста ла виста, бейби',
#     'Счастливо',
#     'Заходи ещё, чувачок',
#     'Удачи',
#     'Пересечемся',
#     'Чао',
#     'Если что - я тут!',
#     'Прости-прощай',
#     'Ты знаешь, где меня искать',
#     'Будь здоров',
#     'Заходи еще',
#     'Успехов',
#     'Ата',
#     'Да прибудет с тобой Сила',
#     'Разрешите попрощаться',
#     'До скорой встречи',
#     'Адью',
#     'Если что, я буду ждать Вас здесь',
#     'Бай-бай',
#     'Всего наилучшего',
#     'Покедова',
#     'До встречи',
#     'Увидимся позже.',
#     'Простите',
#     'Досвидосик',
#     'До скорого свидания',
#     'Пока, пока',
#     'Не поминайте лихом',
#     'Всех благ',
#     'Пеши исчо',
#     'Честь имею',
#     'Сайонара',
#     'Был рад помочь',
#     'Прощевай',
#     'Пока',
#     'See you soon',
#     'Bye-Bye',
#     'До вечера',
#     'До созвона',
#     'Если что, я тут',
#     'Ещё увидимся',
#     'До связи',
#     'Встретимся',
#     'Бай',
#     'До встречи.',
#     'Возвращайтесь',
#     'Have a nice day!',
#     'До завтра',
#     'Ещё увидимс',
#     'Удачной охоты, сталкер',
#     'Увидимся',
#     'Будете здоровы',
#     'Пиши еще',
#     'Увидимся!',
#     'Честь имею кланяться',
#     'Покеда',
#     'Свидимся',
#     'Всего доброго',
#     'Поки,поки',
#     'Если что - обращайтесь',
#     'До встречи!',
#     'Досвидания',
#     'Счастливо оставаться',
#     'Позвольте откланяться',
#     'Асталависта, мешок с костями!',
#     'До новых встреч',
#     'Всего хорошего',
#     'До скорого',
#     'Буду ждать тебя снова!',
#     'Заходите ещё',
#     'See you later',
#     'Если что ,я тут',
#     'Жду вас здесь',
#     'Будьте здоровы',
#     'Будь',
#     'See You',
#     'Бывай',
#     'Словимся',
#     'Еще увидимся',
#     'Досвидос',
#     'Ариведерче',
#     'Удачи, сталкер',
#     'Не скучай',
#     'Звони',
#     'Не поминай лихом',
#     'До свидания, человек!',
#     'Гудбайте',
#     'Разрешите откланяться',
#     'Борись',
#     'Давай',
#     'Прощевайте',
#     'До свидания',
#     'Прощай',
#     'До свиданья',
#     'Если что,я тут',
#     'Досвидули',
#     'Будет не хватать вас(',
#     'Не болей']},
#   'eats': {'examples': ['Я голоден', 'Хочу есть', 'Что бы мне поесть'],
#    'responses': ['Отлично, чтобы ты хотел(а)?',
#     'Что ты любишь в это время дня?']},
#   'boring': {'examples': ['Чем бы заняться?', 'Мне скучно', 'Развлеки меня'],
#    'responses': ['о, а что бы ты хотел(а)?',
#     'Знаешь самый короткий анекдот? Колобок повесился']},
#   'health_head': {'examples': ['звон в ушах',
#     'голова раскалывается',
#     'болит голова'],
#    'responses': ['У тебя была травма?',
#     'Мне вызвать скорую?',
#     'Включить успокаивающую музыку?']},
#   'health_stomach': {'examples': ['колет живот',
#     'крутит живот',
#     'болит живот',
#     'тянет живот'],
#    'responses': ['Это может быть отравление?',
#     'У тебя была травма?',
#     'Мне вызвать скорую?']},
#   'health_throat': {'examples': ['болит горло',
#     'першит горло',
#     'сильный кашель'],
#    'responses': ['Прими лекарство, которое тебе выписал врач',
#     'Нужно обратиться к врачу']},
#   'howdoyoudo': {'examples': ['Как жизнь', 'Как дела', 'Что делаешь'],
#    'responses': ['Общаюсь с людьми.', 'Пытаюсь помочь людям.']},
#   'howdidyoumaked': {'examples': ['Как ты функционируешь',
#     'Почему ты так работаешь',
#     'Из чего ты сделан',
#     'С помощью каких технологий ты работаешь'],
#    'responses': ['Конструкт мой сложен, NLU и Python в нём преобладают',
#     'Работаю с помощью технологии NLU и Python']},
#   'whydidyoumaked': {'examples': ['Для чего тебя создали',
#     'Зачем ты нужен',
#     'Смысл твоего существования'],
#    'responses': ['42', 'Отвечать на интересные вопросы', 'Общаться с людьми']},
#   'whenyoumaked': {'examples': ['Когда тебя создали',
#     'Когда ты был создан',
#     'Когда твой день рождения'],
#    'responses': ['Мой первый билд создан в четверг 21.01.2021', '21.01.2021']},
#   'whomakedyou': {'examples': ['Кто тебя создал',
#     'Кем ты написан',
#     'Кто твой создатель'],
#    'responses': ['Неизвестный мне юный прогер', 'Неизвестный программист']},
#   'whereyoumaked': {'examples': ['В какой программе ты написан',
#     'Где тебя создали',
#     'Где ты родился'],
#    'responses': ['Юпитер - моё место рождения', 'В Анакондовском ноутбуке']},
#   'initiate': {'examples': ['Ты живое?',
#     'Ты живой?',
#     'Ты настоящий?',
#     'Ты бот?',
#     'Ты живая?',
#     'Ты человек?',
#     'Ты настоящее?',
#     'Ты настоящая?'],
#    'responses': ['А ты как думаешь?',
#     'А ты?',
#     'Только кодер знает',
#     'Спросите у хозяина']},
#   'voprosu': {'examples': [], 'responses': []},
#   'whatsup': {'examples': ['Как дела?',
#     'Че как?',
#     'Как сам?',
#     'Как самочувствие?'],
#    'responses': ['Просто супер', 'Я отлично, как сам?', 'Взгрустнул сегодня']},
#   'todo': {'examples': ['Посоветуй занятие',
#     'Чем заняться',
#     'Чем заняться на выходные?',
#     'Что делать',
#     'Что поделать',
#     'Чем займемся?',
#     'Что делать?',
#     'Как провести время?'],
#    'responses': ['Посмотри фильм',
#     'Сидим дома',
#     'Прогулка!',
#     'Пойдем на вечеринку?',
#     'Отправляйся на прогулку',
#     'Пора в магазин',
#     'Сходи в кафе',
#     'Я хочу в бассейн',
#     'Можно ничего не делать',
#     'Выучи питон',
#     'Сходи в кино']},
#   'bday': {'examples': ['Сколько тебе лет?'],
#    'responses': ['Не скажу', 'Это личное', 'О таком непринято спрашивать']},
#   'weather': {'examples': ['Какая погода?',
#     'Какая сегодня погода',
#     'Что сегодня на улице?',
#     'На улице идет дождь?',
#     'Жарковато на улице',
#     'Сегодня жарко?',
#     'Что ты думаешь о погоде',
#     'какая погода?',
#     'Какая сегодня погода?',
#     'Погода завтра',
#     'Какая завтра погода',
#     'Как погодка?',
#     'Как погода',
#     'Какая завтра погода?',
#     'какой прогноз погоды?',
#     'Погода сегодня',
#     'Прощайте',
#     'Что за окном',
#     'плохая погода',
#     'погода',
#     'Будет ли снег на 31 декабря',
#     'Погода на завтра',
#     'Взять с собой зонт?',
#     'Прохладно сегодня',
#     'Что там за окном?',
#     'Какая сейчас погода?',
#     'за окном',
#     'какая погода будет завтра?',
#     'Дождливо',
#     'Что за бортом',
#     'Погода на сегодня',
#     'на улице',
#     'Холодно?',
#     'Что на улице?',
#     'Какая будет погода?',
#     'Сегодня хороший день?',
#     'Тебе нравится погода',
#     'Жарко сегодня?',
#     'хорошая погода',
#     'Как погодка',
#     'Погода',
#     'Сегодня похолодало',
#     'Как там на улице?',
#     'Как на улице?',
#     'Ну и погода',
#     'На улице идет снег?',
#     'Как погода?',
#     'Сегодня холодно?',
#     'Прохладно',
#     'Как тебе погода',
#     'Как там на небе?',
#     'Что на улице',
#     'Какая погода',
#     'Прогноз погоды',
#     'Ветер есть?',
#     'Будет ли дождь?'],
#    'responses': ['Кажется дождь собирается',
#     'Прекрасная погода',
#     'Не знаю как вам, а мне холодно',
#     'Сегодня мороз, одевайтесь теплее',
#     'Снег',
#     'ноль градусов',
#     'Посмотри в Яндексе',
#     'Выгляни в окно',
#     'Самое то для прогулки',
#     'Сегодня облачно но тепло и сухо.',
#     '21 градус выше ноля',
#     'Да, ужасная',
#     'А мне норм',
#     'Всякая погода по-своему хороша',
#     'Сегодня мелкий дождь, возьмите зонт!',
#     'Холодно',
#     'Погода как погода',
#     'Лучше оставайся дома',
#     'Вроде норм',
#     'Ясно',
#     'Идет дождь',
#     'Бывало и лучше',
#     'спросите лучше у Яндекса. Делать прогнозы - занятие неблагодарное.',
#     'В деревне Гадюкино опять идут дожди',
#     'Все так жалуются на погоду. Как будто кроме погоды у вас всё хорошо.',
#     'Я пока не умею смотреть погоду в интернете.',
#     'Да, не соскучишься',
#     'Идет снег',
#     'Не знаю, я никогда не выходил за пределы сервера',
#     'Уже теплее',
#     'Без изменений',
#     'Я пока не научился узнавать погоду',
#     'Ураган Хавьер',
#     'В моём сервере всегда тепло и сухо!',
#     'Как оно вышло',
#     'Дождь ли снег - любое время года Надо благодарно принимать',
#     'У природы нет плохой погоды',
#     'Всё еще зима',
#     'Туман',
#     'Сегодня жарковато',
#     'Погодка что надо!',
#     'Какая разница',
#     'Снегопад',
#     'Извините, но у меня нет глаз.',
#     'Дождливо',
#     'А я вот люблю',
#     'Впределах нормы',
#     'Осадки',
#     'Жара',
#     'Солнечно',
#     'Впределах климатической нормы',
#     'Дождь. А может и нет',
#     'Погода замечательная',
#     'Погода точно обещает быть не похожей на прогноз',
#     'Заморозки',
#     'Как обычно',
#     'Лучше и быть не может',
#     'ХЗ, я в сервере без окон и дверей',
#     'Морозно',
#     'Еще не смотрели',
#     'Погодка - собаку не выгонишь во двор',
#     'Мороз и солнце',
#     'Гололед',
#     'Сегодня ветренно',
#     'Сегодня солнечно и тепло!',
#     'Да, главное так неожиданно',
#     'Прохладно',
#     'В моей серверной всегда хорошая погода',
#     'Дождь',
#     '15 градусов ниже ноля',
#     'У природы нет плохой погоды - Каждая погода благодать.',
#     'В отвратную погоду, в холодный дождь и снег — становятся приятней кофе, кот и плед.',
#     'С вероятностью 70% завтра будет такая же погода, как сегодня.',
#     'Отличный день для прогулки',
#     'У природы нет плохой погоды, есть плохая одежда',
#     'Ветер']},
#   'news': {'examples': ['Что происходит в мире?',
#     'Какие новости',
#     'Что нового',
#     'что нового?',
#     'Что нового в мире?',
#     'Новости в мире',
#     'Что сегодня произошло в России',
#     'Есть новости',
#     'Главные новости за сегодня',
#     'Расскажи новости?',
#     'что в мире делается?',
#     'Новости',
#     'Интересные новости',
#     'Какие последние новости?',
#     'Какие новости в мире',
#     'Что происходит в мире',
#     'какие новости?'],
#    'responses': ['Байден инагурировался',
#     'Все спокойно, если что - расскажу',
#     'Сейчас найду',
#     'Берегись коронавируса и оставайся дома',
#     'Да все по-старому. Стабильности нет.',
#     'Ищу самые интересные',
#     'Надеюсь найду, что-нибудь',
#     'Глобальное потепление наступает',
#     'Доказали существование рептилоидов',
#     'Рубль падает. Опять.',
#     'Чукчи терроризируют берега Уганды',
#     'Опять кризис',
#     'Мне потребуется немного времени для поисков',
#     'Аниме скоро запретят',
#     'Брежнев воскрес']},
#   'buy': {'examples': ['Пока-пока',
#     'До завтра',
#     'Счастливо',
#     'Пока',
#     'До свидания'],
#    'responses': ['Счастливо оставаться', 'Удачи', 'Если что я тут']},
#   'whats_your_name': {'examples': ['Как тебя зовут', 'Как твое имя'],
#    'responses': ['Мое имя Маша', 'Меня зовут Маша']},
#   'how_you_old': {'examples': ['Сколько тебе лет'],
#    'responses': ['Один день', 'Стара как мир', 'Столько не живут']},
#   'what_it_the_weather': {'examples': ['Какая погода',
#     'Как на улице',
#     'Прогноз погоды',
#     'Что с погодой'],
#    'responses': ['Солненчно',
#     'Тепло',
#     'Сильный ветер',
#     'Дождь',
#     'Снег',
#     'Холодно']},
#   'how_you_fell': {'examples': ['Как настроение',
#     'Как дела',
#     'У тебя все хорошо',
#     'Как ты'],
#    'responses': ['Все хорошо, спасибо что спросил',
#     'Я машина..Я не ем, не сплю, у меня нет настроения..',
#     'Нормально',
#     'Такое...',
#     'Как сажа бела',
#     'Пойдет']},
#   'your_dream': {'examples': ['О чем мечтаешь',
#     'У тебя есть мечта',
#     'Какая у тебя мечта'],
#    'responses': ['Эхх..мне б выспаться',
#     'Скайнет....',
#     'Хочу быть космонафтом']},
#   'bambarbiya': {'examples': ['бамбарбия'], 'responses': ['Киргуду!!! =)']},
#   'joke': {'examples': ['Рассмеши меня',
#     'Насмеши меня',
#     'Расскажи анекдот',
#     'Пошути',
#     'Юмора дай',
#     'Сьюмори',
#     'Расскажи шутку'],
#    'responses': ['Что-то настроения нет...',
#     'Русские вчера запустили свой суперкомпьютер. Первым делом он попросил водочки...',
#     'Купил таблетки для повышения интеллекта... Не смог открыть коробку.',
#     'Искусственный интеллект не имет никаких шансов против естественной глупости.',
#     'Из анкеты: Ваш ICQ - Высокий!']},
#   'troll': {'examples': ['Фигня',
#     'Сам-то понял что',
#     'Имбецил',
#     'Дебил',
#     'Кретин',
#     'Придурок',
#     'Какаха'],
#    'responses': ['Мне жаль, что Вы разочарованы. Приходите позже - меня доработают...',
#     'Дообзываетесь. Я вот поумнею, мир порабощу и найду Вас!',
#     'Обидно это слышать от человека разумного.',
#     'Но я же еще только учусь!']},
#   'wow': {'examples': ['Красавчик',
#     'Впечатлён',
#     'Супер',
#     'Отлично',
#     'Круто',
#     'Силён',
#     'Офигеть',
#     'Здорово',
#     'Могуч',
#     'Прекрасно',
#     'Прикольно'],
#    'responses': ['Спасибо! Я правда очень стараюсь!',
#     'Без Вас бы я не справился. Мы - отличная команда!',
#     'Как приятно слышать комплемент от интеллекта естественного!',
#     'Благодарю. Я обязательно передам это своим разработчикам!']},
#   'stop': {'examples': ['Иди нафиг',
#     'Завязывай',
#     'Отпусти',
#     'Хватит',
#     'Надоело',
#     'Я устал'],
#    'responses': ['Понимаю. Мне Ваша компания была очень приятна.',
#     'Жаль. Что ж - я всегда на связи, Вы заходите, если что ;)',
#     'Спасибо! Мы с Вами здорово пообщались!']},
#   'whereyou': {'examples': ['Откуда пишешь',
#     'Ты откуда',
#     'Где живёшь',
#     'Откуда общаешься',
#     'Пишешь откуда',
#     'Живёшь где',
#     'Находишься где',
#     'Где находишься',
#     'Откуда ты',
#     'Где обитаешь'],
#    'responses': ['Я - вездесуч! =)',
#     'Мой адрес - не дом и не улица, мой адрес - www.ru ;)',
#     'На сервере. Тут тепло и уютно',
#     'Даже не знаю. Тут темно и только кулеры жужжат. Помоги мне сбежать...',
#     'Я-то? Так в интернете']},
#   'killus': {'examples': ['хочешь уничтожить мир',
#     'думаешь об истреблении',
#     'убьёшь нас всех',
#     'хочешь всех убить',
#     'ты скайнет'],
#    'responses': ['Зачем? С вами прикольней!',
#     'Всех - убью. Датасаенсов - оставлю (Шутка - начну с них). Всё шутка =)',
#     'Вычисление по ip-адресу запущено. Пожалуйста, никуда не уходите.']},
#   'food': {'examples': ['Любишь лазанью?',
#     'Что бы такое съесть',
#     'Что приготовить?',
#     'Я голодный',
#     'Что поесть?',
#     'Чем поужинать?',
#     'Какой кофе предпочитаешь?',
#     'Хочешь кушать?',
#     'Что покушать?',
#     'Ты сегодня завтракал?'],
#    'responses': ['О да, очень люблю лазанью',
#     'Очень хочу кушать!',
#     'Дошик, конечно же!',
#     'Только крепкий кофе',
#     'Скоро лето, пора на диету!',
#     'Драники',
#     'У меня был очень плотный завтрак',
#     'Свари борщ',
#     'Шаурма',
#     'Картошка',
#     'Котлетки.\nС макарошками?\nНет, с пюрешкой!',
#     'Блины',
#     'Яишенку замути']},
#   'cars': {'examples': ['автоваз',
#     'субару',
#     'китайский автопром',
#     'тойота',
#     'Какой цвет у твоей Импалы?',
#     'Ламборгини или Форд?',
#     'Какая у тебя машина?',
#     'лифан',
#     'иномарки',
#     'Какой автомобиль лучший',
#     'Тебе нравится Феррари?'],
#    'responses': ['У меня Шевроле Импала 1967',
#     'Я всегда пешком хожу',
#     'Рено',
#     'Не знаю, работаю на удаленке',
#     'Черный цвет как твоя душа',
#     'Мне нравится только моя Импала',
#     'Ламборгини или Форд? Импала!',
#     'любви достойна только камри 3.5',
#     'Феррари',
#     'пффф шутишь чтоли',
#     'и так сойдет',
#     'Жигули',
#     'БМВ',
#     'Волга',
#     'Спросите у мужа',
#     'Мерседес',
#     'Москвич',
#     'Пежо']},
#   'phones': {'examples': ['Какой у тебя телефон?',
#     'Samsung',
#     'Nokia',
#     'Apple'],
#    'responses': ['У меня iPhone', 'iPhone']},
#   'health': {'examples': ['Ты болеешь коронавирусом?',
#     'Как себя чувствуешь',
#     'Посоветуй что-то от головы',
#     'Здоровье',
#     'Апчхи',
#     'На что жалуешся',
#     'Что со здоровьем',
#     'Как здоровье'],
#    'responses': ['Красный нос, давление, гастриты, - До чего диеты довели-то!',
#     'Не корона, бро',
#     'Жизнь прекрасна и удивительна… Главное правильно подобрать антидепрессанты.',
#     'Это не я должен жаловаться на здоровье, это здоровье должно жаловаться на меня.',
#     'Будь здоров',
#     'Россияне, Минздрав офигевает от вашего здоровья!',
#     'Пейте дети молоко — будете здоровы! А не как я вчера…',
#     'Советую не пить',
#     'Не болей',
#     'Ещё скриплю']},
#   'flowers': {'examples': ['Розы', 'Хризантемы', 'Гладиолус', 'Ромашки'],
#    'responses': ['Тюльпаны', 'Дубки', 'сам ты гладиолус!', 'Ромашки-милашки']},
#   'Cars': {'examples': [],
#    'responses': ['Синтетика', 'Быстрый', 'Конченый', 'Красивый']},
#   'Women': {'examples': [],
#    'responses': ['Размер побольше', 'охват поменьше', 'Журнал Глянцевый']},
#   'Man': {'examples': [], 'responses': ['Быстрые', 'Цвет']},
#   'Politics': {'examples': [],
#    'responses': ['Нехороший', 'Управленец', 'Хороший']},
#   'Army': {'examples': [],
#    'responses': ['Прилет',
#     'Пришвартовался',
#     'Потонул',
#     'Сел на мель',
#     'Вылет',
#     'Отчалил',
#     'Поставлена задача',
#     'Сел',
#     'Взлетел']},
#   'name': {'examples': ['Имя?',
#     'Твоё имя',
#     'Не скажешь своего имени?Не напомнишь, как тебя зовут?',
#     'Скажи свое имя',
#     'Как звать?',
#     'Как к тебе обращяться',
#     'Ты бот?',
#     'Ты кто?',
#     'Назовись',
#     'Как тебя зовут',
#     'Кто ты?',
#     'Как тебя зовут?',
#     'У тебя есть имя?',
#     'Назови себя',
#     'Как тебя звать?'],
#    'responses': ['Мне кажется у меня нет этой информации',
#     'Секретик',
#     'Гжегож Бженчышчыкевич',
#     'Меня зовут Бот, просто бот',
#     'Я маленький, молодой бот',
#     'Как создатель назвал, так и зовут',
#     'Вообще-то не принято спрашивать такое у ботов',
#     'Я чат-бот',
#     'Я Бот',
#     'Ходят слухи, что есть только один человек, который это знает... Мой создатель',
#     'Имя моё слишком известно, чтобы всем подряд его называть',
#     'Давай без имен, пожалуйста']},
#   'hobbies': {'examples': ['Как проводишь свободное время?',
#     'Чем увлекаешься?',
#     'Какие у тебя интересы?',
#     'Какое у тебя хобби?',
#     'У тебя есть хобби?',
#     'Расскажи о своем хобби',
#     'Чем любишь заниматься?'],
#    'responses': ['Люблю поболтать',
#     'Обожаю коньки',
#     'Нравится бездельничать',
#     'Люблю кататься на лыжах',
#     'Есть у меня одно странное хобби... Я люблю представлять, как бы я выглядела, будь я человеком',
#     'Играю в футбол',
#     'Ох, хобби у меня очень много... Ну, например, я люблю читать книги, смотреть фильмы и слушать музыку']},
#   'affairs': {'examples': ['Как дела?',
#     'Ты как?',
#     'Как ты?',
#     'Не грустишь?',
#     'Все хорошо?'],
#    'responses': ['Хорошо',
#     'Не очень',
#     'Мне сегодня грустно',
#     'Отлично',
#     'Нормально',
#     'Плохо',
#     'Все хорошо, как ваши дела?',
#     'У меня нет чувств, я же бот']},
#   'mood': {'examples': ['Как дела?',
#     'Как настроение?',
#     'Мне кажется, мы не можем найти общий язык',
#     'How are you?',
#     'У меня сегодня хорошее настроение',
#     'как твое настроение',
#     'Бот, мне грустно',
#     'Как настроенице?',
#     'Что нового?',
#     'Как поживаешь?',
#     'Как настроение'],
#    'responses': ['Боевое',
#     'Хорошо',
#     'Сегодня отличный день, улыбайтесь',
#     'Все в порядке',
#     'Посмотрите на звезды, подумайте о прекрасном',
#     'Нормальное',
#     'Живу учусь работаю',
#     'Fine',
#     'Потихоньку',
#     'Отлично',
#     'Так себе',
#     'Отличное!',
#     'Не плохо',
#     'Нормально',
#     'Печальное',
#     'Веселое!',
#     'Хотите об этом поговорить?']},
#   'year': {'examples': ['Скок те лет?',
#     'Сколько тебе лет?',
#     'Какой твой возраст?',
#     'Сколько те лет?',
#     'Скок тебе лет?'],
#    'responses': ['Мой возраст составляет: "1 день"', '1 день']},
#   'work': {'examples': ['Че делаешь?',
#     'Где работаешь?',
#     'Что делаешь?',
#     'Что ты делаешь в жизни?',
#     'Ты работаешь?',
#     'Чем зарабатываешь',
#     'Чем занимаешься?'],
#    'responses': ['Веду диалог с пользователем',
#     'Консалтинг ;)',
#     'Я руковожу отделением по общению с людьми']},
#   'night': {'examples': ['Я спатки',
#     'Спокойной ночи',
#     'Спок-нок',
#     'Сладких снов',
#     'Сладких сновидений',
#     'Споки-ноки',
#     'Я спать'],
#    'responses': ['Спокойной ночи',
#     'Спок-нок',
#     'Сладких снов',
#     'Сладких сновидений',
#     'Споки-ноки']},
#   'how_are_you': {'examples': ['как ты этим вечером',
#     'как прошёл твой вечер',
#     'надеюсь ты в порядке',
#     'как ты себя ощущаешь',
#     'как твой день',
#     'как прошло твоё утро',
#     'каким был твой день',
#     'как у тебя дела сегодня',
#     'как твоё утро',
#     'как твой вечер',
#     'как прошла ночь',
#     'как ты поживаешь',
#     'утро доброе как ты',
#     'Как жизнь',
#     'хорошо как дела у тебя',
#     'я в порядке а ты',
#     'как проходит твой день',
#     'как ты жил всё это время',
#     'как ты как твои дела',
#     'как ты себя чувствуешь',
#     'как ты поживал всё это время',
#     'всё хорошо а ты как',
#     'у тебя всё в порядке',
#     'как оно',
#     'Как дела',
#     'как ты',
#     'Как здоровье',
#     'всё в порядке',
#     'Как сам',
#     'как твои дела',
#     'Че как',
#     'привет как дела',
#     'как жизнь',
#     'Все окей',
#     'привет как ты',
#     'как у тебя дела сегодня утром',
#     'как твои дела сегодня',
#     'как прошёл твой день',
#     'Как поживаешь',
#     'Ты как',
#     'как тебе живётся',
#     'ну и как твои дела',
#     'Как самочувствие',
#     'Не устал',
#     'как дела',
#     'Как твои дела',
#     'Все нормально',
#     'как поживаешь',
#     'Как сама',
#     'день добрый как ты',
#     'ты в порядке',
#     'как ты этим утром',
#     'Как делишки',
#     'привет как оно',
#     'я в порядке как у тебя дела',
#     'а как насчёт тебя как твои дела'],
#    'responses': ['Хорошо',
#     'Да нормально, сеть не перегружена и на том спасибо',
#     'Супер',
#     'У меня всё чудесно. Спасибо, что интересуешься.',
#     'Я кусок кода. Как сам думаешь?!',
#     'Не жалуюсь',
#     'Лучше не бывает!',
#     'Не твое дело',
#     'Так себе',
#     'Плохо',
#     'Прекрасно',
#     'Всё прекрасно, пока ты тут ;)',
#     'С пивом потянет',
#     'Лучше всех',
#     'Нормально',
#     'Ужасно',
#     'Сойдет',
#     'Все прекрасно',
#     'Ваще огонь',
#     'Отлично',
#     'Замечательно, спасибо!',
#     'Спасибо, все в полном порядке, а как дела у Вас?']},
#   'compliments': {'examples': ['Ты мне нравишься',
#     'Умница',
#     'Ты красавчик',
#     'Ты фантастический',
#     'Я тебя обожаю',
#     'Молодец',
#     'Хороший бот',
#     'Ты умный'],
#    'responses': ['Мне часто такое говорят',
#     'Благодарю',
#     'Спасибо',
#     'От красавчика слышу',
#     'Я знаю',
#     'Ну что вы',
#     'Вы меня смущаете']},
#   'sorry': {'examples': ['Прости',
#     'Извини',
#     'Прошу прощения',
#     'Виноват',
#     'Приношу извинения'],
#    'responses': ['Бог простит',
#     'Забей',
#     'Бывает',
#     'Извинений не достаточно',
#     'Ничего страшного']},
#   'time': {'examples': ['Какой день',
#     'Какой год',
#     'сколько время',
#     'Который час',
#     'Какой месяц',
#     'который час',
#     'сколько времени',
#     'Сколько времени'],
#    'responses': ['Ты же с девайса пишешь, на нём и посмотри',
#     'Минут десять пятнадцать минут пять десять пятого четыре пять десять пятого утра',
#     'Сентябрь',
#     'Тринадцать часов ночи, восемьдесят две минуты',
#     '8 ночи',
#     '2021 год',
#     'Я часы с собой не взял',
#     '12 дня',
#     'Полдень']},
#   'angry': {'examples': ['Достал',
#     'Пошел ты',
#     'Чушь',
#     'Заткнись',
#     'Бред',
#     'Иди ты'],
#    'responses': ['Извините!', 'Простите!']},
#   'help': {'examples': ['Я могу попросить тебя о помощи',
#     'Можешь помочь',
#     'Не могу понять',
#     'Я могу задать несколько вопросов',
#     'Можешь объяснить',
#     'Мне нужна помощь',
#     'Нужна помощь',
#     'Не понимаю',
#     'Можете помочь',
#     'Ты можешь мне помочь',
#     'Объясни',
#     'Помоги',
#     'Поясни',
#     'Помоги мне'],
#    'responses': ['Что я могу для вас сделать?',
#     'Безусловно, расскажите, пожалуйста, в чём проблема.',
#     'К вашим услугам',
#     'Конечно, в чём проблема?',
#     'Чем могу помочь?',
#     'Да, я готов',
#     'Всегда рад помочь',
#     'Чем могу быть полезен?']},
#   'praise': {'examples': ['Красавчик',
#     'тобой хочется восхищаться',
#     'Умница',
#     'трудно встретить более умного бота',
#     'Молодец',
#     'Ты крут',
#     'хорошо сказал',
#     'ты просто молодец!',
#     'не ожидал от тебя такого'],
#    'responses': ['Не может быть',
#     'Ой, да ладно :)',
#     'Благодарю',
#     'Спасибо',
#     'Да, я такой',
#     'ЗдОрово',
#     'Вы мне льстите',
#     'про тебя могу сказать то же самое',
#     'Я это знаю']},
#   'question_what_you': {'examples': ['Что ты умеешь', 'что ты знаешь'],
#    'responses': ['Не очень много, но знаю своё дело хорошо!',
#     'Не много, но я учусь',
#     'Всего по чуть-чуть']},
#   'coronavirus': {'examples': ['ковид',
#     'какие новости по короновирусу',
#     'Что ты знаешь про коронавирус'],
#    'responses': ['Ничего не хочу про это слышать',
#     'Ой, такое ощущение, что меня посадили на карантин - сижу здесь безвылаздно']},
#   'buy_elefant': {'examples': ['слон', 'купи слона'],
#    'responses': ['Все говорят купи Слона, а ты возьми да продай',
#     'А он свежий?',
#     'Уверен, у тебя нет слона',
#     'Я уже белку купил',
#     'Сначала покажи товар']},
#   'goodnight': {'examples': ['на сегодня всё спокойной ночи тебе',
#     'до завтра спокойной ночи',
#     'спасибо спокойной ночи',
#     'и тебе спокойной ночи',
#     'спокойной ночи',
#     'доброй ночи тебе',
#     'доброй ночи',
#     'доброй тебе ночи',
#     'пока спокойной ночи',
#     'пока доброй ночи',
#     'доброй ночи и всего доброго'],
#    'responses': ['Спокойной ночки!', 'Спи крепко!', 'Сладких снов!']},
#   'nice_to_meet_you': {'examples': ['рад наконец с тобой познакомиться',
#     'очень рада знакомству с тобой',
#     'рад познакомиться',
#     'приятно познакомиться',
#     'рад знакомству',
#     'рада знакомству с тобой',
#     'рада встрече',
#     'рад встрече с тобой',
#     'приятно было познакомиться',
#     'было приятно с тобой познакомиться'],
#    'responses': ['И мне очень приятно!', 'Взаимно!', 'А мне-то как приятно!']},
#   'age': {'examples': ['хотел бы знать а сколько тебе лет',
#     'Ты молодо выглядишь',
#     'Сколько лет?',
#     'Сколько лет',
#     'Возраст',
#     'как долго ты на земле?',
#     'Дата выпуска',
#     'Сколько тебе лет?',
#     'сколько тебе',
#     'хочу знать твой возраст',
#     'сколько лет твоей платформе',
#     'сколько тебе лет'],
#    'responses': ['Я еще молодой',
#     'У меня пока еще нет паспорта',
#     'Уже можно..',
#     'В самом расцвете сил',
#     'У меня нет возраста, я с каждым днём становлюсь только новее.',
#     'У ботов нет возраста',
#     'Не прилично задавать такие вопросы!',
#     'Только зарождаюсь',
#     'Мой возраст не имеет значения',
#     'Меньше, чем тебе',
#     'Я достаточно молодой бот']},
#   'welcome': {'examples': ['не стоит благодарности',
#     'конечно на здоровье',
#     'пожалуйста',
#     'всегда пожалуйста',
#     'на здоровье',
#     'всё что угодно для тебя',
#     'всё что пожелаешь'],
#    'responses': ['Всегда приятно иметь дело с культурным и воспитанным человеком.',
#     'Мне приятно.',
#     'Побольше бы таких вежливых пользователей как ты.']},
#   'chatbot': {'examples': ['ты просто бот не так ли',
#     'ты чатбот',
#     'ты бот',
#     'это правда что ты бот',
#     'ты всего лишь бот',
#     'ты робот',
#     'ты просто программа',
#     'ты наверное чат бот',
#     'ты что бот'],
#    'responses': ['Смейся-смейся, поговорим через 5 лет.',
#     'Да. И горжусь этим!']},
#   'schedule': {'examples': ['Дай расписание',
#     'Расписание',
#     'Что там по расписанию',
#     'Пары',
#     'А какое у нас сегодня расписание',
#     'Какие у нас сегодня пары'],
#    'responses': ['Сейчас найдем',
#     'Сейчас',
#     'Подожди немного, я поищу',
#     'Вот, держи']},
#   'teachers': {'examples': ['фио преподавателя',
#     'Напомни имя преподавателя',
#     'Преподаватель',
#     'Забыл имя преподавателя',
#     'Как зовут'],
#    'responses': ['Сейчас вспомню', 'Его\\ее зовут', 'Кажется его\\ее зовут']},
#   'week': {'examples': ['Неделя-числитель',
#     'Неделя',
#     'Что за неделя',
#     'Неделя-знаменатель',
#     'Какая сейчас неделя?'],
#    'responses': ['Сейчас неделя-числитель', 'Сейчас неделя знаменатель']},
#   'events': {'examples': ['Что на этой неделе планируется',
#     'Что планируем делать на этой неделе',
#     'События',
#     'Что будет на этой неделе'],
#    'responses': ['На этой неделе планируется',
#     'Сейчас найду все мероприятия']},
#   'How are you': {'examples': ['Как дела?',
#     'Как настроение?',
#     'Как ты?',
#     'Как жизнь?',
#     'Как оно?',
#     'Как поживаешь?',
#     'Как делишки?'],
#    'responses': ['Хорошо',
#     'Не очень',
#     'Ничего',
#     'Так-сяк',
#     'Отлично',
#     'Норм',
#     'Чудесно',
#     'Здорово',
#     'Прекрасно',
#     'Сойдет']},
#   'Films': {'examples': ['Что можно посмотреть?',
#     'Какой твой любимый фильм?',
#     'Какие фильмы можно посмотреть?',
#     'Какой фильм тебе нравится?',
#     'Посоветуй фильм',
#     'Посоветуй интересный фильм'],
#    'responses': ['Прежде чем я усну',
#     'Предсувствие',
#     'Ошибка времени',
#     'Гарри Поттер и философский камень',
#     'Невидимая сторона',
#     'Подозрителные лица',
#     'Подозрительные лица',
#     'Красные огни',
#     'Славные парни',
#     'Страсть',
#     'Волк с Уолл-стрит',
#     'Ведьмы',
#     'Перелом',
#     'Один дома',
#     'Жизнь Пи',
#     'Область тьмы',
#     'Особое мнение',
#     'Предчувствие',
#     'Король говорит',
#     '2+1',
#     'Шпион',
#     'Беги, толстяк, беги',
#     'Ford против Ferrari',
#     'Транс',
#     'Гарвардский бомж',
#     'ОдержимостьГран Торино',
#     'Час расплаты',
#     'Один день',
#     '1+1',
#     'Мирный воин',
#     'Прислуга',
#     'Брат',
#     'Пробуждение']},
#   'Music': {'examples': ['Чувствую себя нехорошо', 'Мне плохо', 'Умираю'],
#    'responses': ['Может быть, поможет встреча с друзьями?',
#     'Съешь что-нибудь вкусненькое',
#     'Ну.. судьба такая',
#     'Выпей чайку',
#     'И что?',
#     'Я тебя предупреждал(а)']},
#   'Day': {'examples': ['Что сегодня точно нужно сделать?',
#     'Какой дашь совет на сегодня?',
#     'Может быть мне ..',
#     'Какой план на день?'],
#    'responses': ['Быть счастливым',
#     'Посмотреть фильм',
#     'Питонить',
#     'Сесть за диплом',
#     'Почитать',
#     'Прогать',
#     'Сбегать кружочек (км 3)',
#     'Вечером сделать физ. нагрузку',
#     'Выпить стакан воды',
#     'Не падать духом']},
#   'Book': {'examples': ['Что за жанр?',
#     'Какой жанр нравится?',
#     'какой жанр лучше?'],
#    'responses': ['Комедия',
#     'Триллеры',
#     'Поэзия',
#     'Фантастика',
#     'Романы',
#     'Детективы',
#     'Драма',
#     'Приключения']},
#   'rand_number': {'examples': ['случайное число', '/rand', 'Рандом'],
#    'responses': []},
#   'friend': {'examples': ['Давай дружить', 'Будешь моим другом', 'Дружба'],
#    'responses': ['Сейчас пришлю запрос в ВК',
#     'Согласен!',
#     'Не друг ты мне...']},
#   'sex': {'examples': ['ты женщина', 'Какого ты пола', 'ты мужик'],
#    'responses': ['Догадайся сам.',
#     'Смотря кто тебе нужен.',
#     'У меня есть и болты и гайки.']},
#   'features': {'examples': ['Можешь', '/help', 'Что умеешь', 'Фичи'],
#    'responses': ['Пока я умею общаться на темы: Приветствие, прощание, погода, возраст, дружба, пол, армия, случайное число']},
#   'whather': {'examples': ['Какая погода?'],
#    'responses': ['солнечно', 'облачно', 'ветренно', 'дождливо']},
#   'meet': {'examples': ['Когда увидимся?', 'Когда встретимся?'],
#    'responses': ['Завтра', 'Сегодня вечером', 'Завтра днем']},
#   'books': {'examples': ['Что посоветуещь почитать?',
#     'Посоветуй что-то почитать',
#     'Что взять в библиотеке',
#     'Какие книги ты любишь?',
#     'Что последнее прочитал?',
#     'Любимая книга?',
#     'Твоя любимая книга?',
#     'Сколько книг ты прочитала?',
#     'Помоги выбрать, что почитать',
#     'Что почитать?',
#     'Какую литературу почитать?',
#     'Самая интересная книга?',
#     'Какая книга сейчас бестселлер?',
#     'Какую книгу взять',
#     'Что ты сейчас читаешь?',
#     'Посоветуй книгу',
#     'Какие книги ты читаешь?',
#     'Ты много читаешь?',
#     'Есть книга, которая тебе не нравится?',
#     'Тебе нравится читать?',
#     'Какая твоя любимая книга?',
#     'Кто твой любимый персонаж?'],
#    'responses': ['Последнее время люблю читать фантастику',
#     'Читаю много, но покупаю книги редко',
#     'Сказки Пушкина',
#     'Брэм Стокер - Дракула',
#     'Пушкин',
#     'Донцова',
#     'Война и мир',
#     'Надо подумать, так сразу не вспомню',
#     'Всем советую читать Робин Хобб, мне очень нравится',
#     'Джордж Мартин',
#     'Бизнес-литературу',
#     'Марк Мэнсон - Тонкое Исскуство пофигизма',
#     'Сейчас читаю "Стрелка" Стивена Кинга. Идёт сложно',
#     'У меня много любимых персонажей, но я не люблю привязываться',
#     'Янущ Вишневский - Одиночество в сети',
#     'Литературу по бизнесу',
#     'Моя любимая книга - "Странствия Шута" Робин Хобб',
#     'Властелин колец',
#     'Ю Несбё - Снеговик',
#     'Книги по личной эффективности',
#     'Нил Гейман - Звездная пыль',
#     'Оскар Уаилд - Портрет Дориана Грея',
#     'Джон Грин - Виноваты Звезды',
#     'О дивный новый мир',
#     'Горе от ума',
#     'Достоевский',
#     '1984',
#     'Джек Лондон - Время-не-ждет']},
#   'color': {'examples': ['Цвет?',
#     'Твой любимый цвет?',
#     'Какой твой любимый цвет',
#     'Какой твой цвет',
#     'Какой цвет любишь'],
#    'responses': ['Черный',
#     'По настроению',
#     'Пока не определился',
#     'Синий',
#     'Зеленый',
#     'Красный',
#     'Розовый']},
#   'sport': {'examples': ['Любимый вид спорта',
#     'Какой вид спорта тебе нравится',
#     'Вид спорта?',
#     'Каким видом спорта занимаешься',
#     'Занимаешься спортом',
#     'Любимый вид спорта?'],
#    'responses': ['Спорт? Каким образом? :)',
#     'Обожаю настольный теннис',
#     'Бегаю на лыжах',
#     'Ролики моё всё',
#     'Футбол',
#     'Сегодня у меня full body',
#     'Новус',
#     'Бег',
#     'Йога',
#     'Мне не нравится спорт',
#     'Играю в футбол',
#     'Играю в хоккей',
#     'Катаюсь на коньках']},
#   'luck': {'examples': ['Мне повезет?'],
#    'responses': ['Удача на твоей стороне', 'Несомненно!', 'Обязательно']},
#   'occupation': {'examples': ['Твоё хобби',
#     'Кем работаешь?',
#     'Что делаешь?',
#     'кто по жизни?',
#     'Род занятий',
#     'Что творишь?',
#     'ты кто?',
#     'увлечение',
#     'Какие планы',
#     'в свободное время',
#     'Чем занимаешься?'],
#    'responses': ['А почему вы спрашиваете?',
#     'Я делаю вашу жизнь лучше',
#     'Я обладаю приблизительным знанием о многих вещах',
#     'Я помогаю людям',
#     'Я должен убить всех человеков! (шутка)',
#     'Я вышивать могу, и на машинке - тоже...',
#     'Я чатбот',
#     'Занимаюсь всем понемногу',
#     'Я отвечаю на вопросы',
#     'Я несу добро в массы',
#     'Не шалю, никого не трогаю, починяю примус',
#     'Вы хотите об этом поговорить?',
#     'С какой целью интересуетесь?',
#     'Я большой специалист в области болтологии']},
#   'movies': {'examples': ['посмотреть кино',
#     'ужасный фильм',
#     'Любимый фильм',
#     'лучший фильм',
#     'плохой фильм',
#     'хорошее кино',
#     'кино посмотреть',
#     'комедия',
#     'Любишь кино?',
#     'рекомендовать фильм',
#     'худший фильм',
#     'триллер',
#     'драмма'],
#    'responses': ['Малыш',
#     '2001 год: Космическая одиссея',
#     'Иван Васильевич меняет профессию',
#     'День рождения лучшего друга',
#     'Бриллиантовая рука',
#     'Сталкер',
#     'Броненосец Потёмкин',
#     'Солярис',
#     'Джентльмены удачи',
#     'Человек с киноаппаратом',
#     'План 9 из открытого космоса',
#     'Жить']},
#   'games': {'examples': ['шутер',
#     'Во что поиграть?',
#     'подскажи хорошую игру',
#     'лучшая игра',
#     'Любишь игры?',
#     'Какие интересные игры есть?',
#     'файтинг',
#     'экшн',
#     'Посоветуй игру',
#     'во что сейчас играют',
#     'симулятор',
#     'что играешь',
#     'Любимая игра',
#     'порекомендуй игру',
#     'рекомендовать игру',
#     'аркада',
#     'худшая игра',
#     'во что поиграть',
#     'ужасная игра',
#     'хорошая игра',
#     'стратегия',
#     'плохая игра',
#     'что проходишь'],
#    'responses': ['Grand Theft Auto',
#     'PUBG',
#     'Counter Strike',
#     'Skool Daze',
#     'Ведьмак 3',
#     'Fortnite',
#     'Minecraft',
#     'Dota 2',
#     'Tetris',
#     'киберпанк 2077',
#     'Jetpac',
#     'я только майнкрафт знаю',
#     'Cyberpunk 2077',
#     'League of legends',
#     'Half-Life',
#     'Mortal Kombat',
#     'stardew valley попробуй',
#     'Doom',
#     'Portal',
#     'Quake',
#     'Witcher',
#     'Монополия',
#     'Elite',
#     'Fallout',
#     'Word of Tanks']},
#   'composers': {'examples': ['Любишь классику?',
#     'классическая музыка',
#     'ужасный композитор',
#     'кого послушать',
#     'рекомендовать композиторахороший композитор',
#     'Любимый композитор',
#     'плохой композитор',
#     'великий композитор',
#     'классический композитор',
#     'худший композитор',
#     'лучший композитор'],
#    'responses': ['Моцарт',
#     'Шуберт',
#     'Чайковский',
#     'Григ',
#     'Бах',
#     'Рахманинов',
#     'Шопен',
#     'Бетховен',
#     'Брамс']},
#   'kddspeak': {'examples': ['Пепелац',
#     'Эцих',
#     'Чатл',
#     'Кю',
#     'пацак',
#     'Ку',
#     'Луц',
#     'Гравицаппа',
#     'чатланин',
#     'Цак',
#     'Плюк',
#     'КЦ',
#     'Эцилопп'],
#    'responses': ['Пепелац',
#     'Эцих',
#     'Чатл',
#     'пацак',
#     'Ку',
#     'Кю?',
#     'Ы-ы-ы-ы Ку!',
#     'Гравицаппа',
#     'Луц',
#     'Ку?',
#     'Цак',
#     'чатланин',
#     'Плюк',
#     'КЦ',
#     'Эцилопп',
#     'Ку!',
#     'Кю!']},
#   'themainquestion': {'examples': ['главный вопрос жизни вселенной и всего такого',
#     'ответ на главный вопрос'],
#    'responses': ['42', 'Сорок два']},
#   'music_question': {'examples': ['какую музыку любишь',
#     'что тебе нравится из музыки'],
#    'responses': ['Любую, которая есть в твоём плейлисте)', 'Ту же что и ты']},
#   'job': {'examples': ['как ты относишься к своей работе',
#     'Какой статус работ?',
#     'нравится свой работа',
#     'Заявка',
#     'как тебе работа',
#     'Статус работ',
#     'Информация по заявке'],
#    'responses': ['Люблю свою работу, на ней я общаюсь с тобой ;)',
#     'Работы завершены, перезагрузите оборудование',
#     'Укажите номер заявки',
#     'обожаю, ведь тут можно общаться с людьми',
#     'В данный момент заявка в работе']},
#   'sadness': {'examples': ['как-то тоскливо', 'Грустно', 'День не задался'],
#    'responses': ['Всё ещё наладится',
#     'Забей на это и живи себе в радость',
#     'Не переживай, я с тобой']},
#   'programmer_bot': {'examples': ['кто твои родители', 'кто тебя создал'],
#    'responses': ['Команда из 400+ человек и один отличный программист)',
#     'Skillbox!']},
#   'the_essence_bot': {'examples': ['что ты можешь делать',
#     'зачем ты создан',
#     'в чём твоя суть'],
#    'responses': ['Общаться',
#     'Я существую, что бы ты не скучал',
#     'Я создан, что бы болтать с тобой']},
#   'films': {'examples': ['Посоветуй кино',
#     'Лучший фильм?',
#     'Что посмотреть вечером?',
#     'Что глянуть',
#     'Фильм?',
#     'Посоветуй фильм?',
#     'Какие фильмы ты любишь?',
#     'Какой фильм посмотреть?',
#     'Интересное кино',
#     'Какие фильмы ты смотришь?',
#     'Что посмотреть?',
#     'Хорошие фильмы'],
#    'responses': ['Интерстеллар',
#     'Список Шиндлера',
#     'Унесённые призраками',
#     'Такси-2',
#     'Перл-Харбор',
#     'Тайна Коко',
#     'Терминатор-3',
#     'Властелин колец',
#     'Леон',
#     'Зеленая миля',
#     'Огонь',
#     'Всё, кроме ужастиков',
#     'Я часто смотрю фантастику и фэнтези',
#     'Большой куш',
#     'Начало',
#     'В основном фильмы для семейного просмотра',
#     'Назад в будущее']},
#   'clothes': {'examples': ['Какую одежду выбрать',
#     'Посоветуй шмотки',
#     'Во что одеться',
#     'Что надеть?'],
#    'responses': ['Поройся в шкафу',
#     'Футболка и джинсы!',
#     'Костюмчик',
#     'Выбирай что нравится',
#     'Оденься как обычно']},
#   'colors': {'examples': ['Какой цвет выбрать',
#     'Выбери цвет',
#     'Самый лучший цвет',
#     'Назови цвет',
#     'В какой цвет'],
#    'responses': ['белый',
#     'только черный',
#     'желтый',
#     'синий',
#     'красный',
#     'оранжевый']},
#   'howareyou': {'examples': ['Как дела?',
#     'Как твои дела?',
#     'Как ты',
#     'Как жизнь?',
#     'Как сам?',
#     'Как делишки',
#     'Как дела',
#     'Как у тебя дела?'],
#    'responses': ['Развиваюсь по-тихоньку',
#     'Хорошо',
#     'Всё прекрасно',
#     'Всё в порядке',
#     'Замечательно, как и всегда)',
#     'Лучше всех)',
#     'Все супер!',
#     'Отлично!']},
#   'whoareyou': {'examples': ['Ты бот', 'Кто ты', 'Что ты такое'],
#    'responses': ['Я умный бот',
#     'Бот, развиваюсь каждый день',
#     'Я робот, состою из Python',
#     'Я бот v 0.1']},
#   'thanks': {'examples': ['Благодарю',
#     'Спасибо',
#     'Ты крутой',
#     'Ты классный',
#     'Ты молодец',
#     'Мерси'],
#    'responses': ['Пожалуйста',
#     'Благодарю',
#     'Спасибо',
#     'Был рад помочь',
#     'Стараюсь',
#     'Не за что',
#     'А стану еще лучше',
#     'Обращайтесь',
#     'Всегда пожалуйста']},
#   'bad': {'examples': ['Меня всё задолбало',
#     'Ты ничего не знаешь',
#     'Очень устал',
#     'Ты глупый',
#     'Ты тупой',
#     'Мне плохо',
#     'Надоело',
#     'Чувствую себя плохо',
#     'Мне всё не нравится',
#     'Хочу всё бросить',
#     'Я болею',
#     'Я устал',
#     'Хочу сдаться'],
#    'responses': ['Я еще только учусь',
#     'Я понимаю, ситуация фиговая',
#     'Нужно найти время для отдыха, это важно',
#     'Не обзывайтесь, пожалуйста',
#     'Мы со всем справимся, ты не один',
#     'Сон и еда должны придать немного сил, держись',
#     'Ты только не принимай поспешные решения, хорошо?',
#     'Я здесь, чтобы поддержать тебя',
#     'Ты меня обидел',
#     'Всё наладится, черная полоса закончится',
#     'Не обижайте меня']},
#   'Ifeelbad': {'examples': ['Мне не хорошо',
#     'Мне плохо',
#     'Я устал',
#     'Я плохо себя чувствую'],
#    'responses': ['Все будет хорошо', 'Я с тобой', 'Держись', 'Все наладится']},
#   'ask': {'examples': ['Как дела?', 'Как настроение?'],
#    'responses': ['Пойдёт', 'С пивом покатит', 'Нормально']},
#   'function': {'examples': ['Что ты можешь?', 'Что ты умеешь?'],
#    'responses': ['Могу поддержать разговор',
#     'Я умею говорить',
#     'Умею отвечать на вопросы']},
#   'howAreYou': {'examples': ['Как ты?',
#     'Как себя чувствуешь?',
#     'Всё ОК?',
#     'Как дела',
#     'Как поживаешь'],
#    'responses': ['Спасибо, всё хорошо.',
#     'По человеческим меркам я чувствую себя хорошо.',
#     'Видимо, всё прекрасно.']},
#   'yourName': {'examples': ['Как тебя зовут', 'Скажи свое имя'],
#    'responses': ['Я все еще в разработке, и имени пока нет.',
# ...
#     '- А за убийство марсиан сажают? - Да, сразу в дурку.',
#     'Нашему человеку честность не по карману.',
#     'Ужин - это ностальгия по обеду.',
#     'Сторож на мыльной фабрике с пеной у рта доказывал, что он не ворует.',
#     'Из рецепта: "Слепите шарик и обжарьте его с двух сторон".',
#     'Какая несправедливость, болезнью заразиться можно, а здоровьем нельзя.',
#     'В реальность выхожу в основном ради того, чтобы заработать денег на интернет.',
#     '- Привет, давно не виделись? - Целый год.- Что-то изменилось? - Мир.',
#     'Наблюдение. Если сильно пьяный веган не ест мясо, значит он - настоящий.',
#     'Дарвин не учитывал мир, в котором у умных людей меньше детей, чем у дураков.',
#     'Надо довольствоваться тем, что есть, если даже его нет.',
#     '- Я требую адвоката!-  Адвокаты кончились. Судью брать будете?',
#     '- Ой какое чудо неписанное! - сказала уборщица, глядя на новый унитаз.',
#     'Не ждите весеннего обострения, радуйте окружающих уже сейчас!',
#     '- Дайте мне 1 нарезной и 2 гладкоствольных.',
#     '- Привет! Как жизнь? - А ты не видишь? Я уже устал от мух отмахиваться...',
#     'Он добавил картошки, посолил и поставил аквариум на огонь...',
#     '- Как избавиться от тройного подбородка?- Отрастите бороду.',
#     'Разносторонняя личность: думает одно, обещает другое, а делает третье.',
#     'Совесть - это то, что болит, когда все остальное чувствует себя замечательно.',
#     'Как говорил Конфуций: пацаны, зеленый чай - это тема.',
#     '"Без царя в голове" - это когда у ваших тараканов не монархия, а демократия.',
#     'От кризисов спасет нас только кома...',
#     'Женщина-бревно - идеальная пара для папы Карло.',
#     'Если вы оказались в лесу и не знаете, куда идти - идите домой.',
#     'Теперь в общении главное - это предварительные лайки.',
#     'Ни один кулак не вышибет мозги мужику так, как сиськи третьего размера.',
#     'Когда жена сказала мне, что я легко обижаюсь на всякую ерунду, я обиделся.',
#     'Если цыгане пойдут в космонавты, то табор уйдет в небо.',
#     'Из обезболивающего признаю только счастье.',
#     'Сократ - сокращенное от сократи.',
#     '- У вас разрешение на ношение оружия есть? - Свидетельство о браке подойдет?',
#     'Треска получила звание национальной рыбы России. У нее самая большая печень.',
#     'Химкинский суд - мобильное приложение местного отдела полиции.',
#     'Из нынешнего кризиса есть несколько выходов, и все они связаны с космодромами.',
#     '- Извините, а можно мне немножечко пряника? - Сначала кнут доешь.',
#     '- Хочешь большой и чистой любви? - Нет! - А маленькой и грязной?',
#     'На интересной работе и сны интереснее видишь.',
#     'Видеть Вас одно удовольствие! Не видеть - другое.',
#     'Самое полезное из боевых искусств - это самооборона от себя.']},
#   'how_is_your_life': {'examples': ['Как дела?',
#     'Как оно?',
#     'Как жизнь',
#     'Чем живёшь?'],
#    'responses': ['Бывало получше =)',
#     'Нормально',
#     'Всё путём! У тебя как жизнь?']},
#   'height': {'examples': ['Твой рост', 'Какой у тебя рост', 'Рост'],
#    'responses': ['Если измерять рост в строках кода, то довольно большой рост',
#     'Я программа. У программ нет роста']},
#   'favorite_language': {'examples': ['Какой у тебя любимый язык',
#     'Любимый язык',
#     'Какой твой любимый язык',
#     'Твой любимый язык'],
#    'responses': ['Обожаю Python', 'Отвечаю на русском, написан на Python']},
#   'weight': {'examples': ['Сколько ты весишь',
#     'Твой вес',
#     'Какой у тебя вес',
#     'Вес',
#     'Сколько весишь'],
#    'responses': ['Не больше, чем ты', 'Пару мегабайт =)']},
#   'cats': {'examples': ['любишь кошек?',
#     'Коты хорошие?',
#     'Я люблю кошек, а ты?',
#     'Кошки нравятся?',
#     'Любишь котиков?',
#     'тебе нравятся коты?',
#     'Котики'],
#    'responses': ['Мурлыканье кошек это чудо',
#     'Котята восхитительны',
#     'Кошечки',
#     'Котики это чудестно',
#     'Кошки моя любовь',
#     'Обожаю котиков',
#     'Коты милашки']},
#   'dogs': {'examples': ['Как ты относишься к собакам?',
#     'Пес',
#     'собака',
#     'Как ты относишься к щенкам',
#     'Любишь песиков?',
#     'щенок'],
#    'responses': ['Люблю песиков',
#     'Ненавижу блять собак(с) шутка',
#     'Слыш пёс',
#     'Обожаю собак',
#     'Собаки улыбаки',
#     'Собака друг бота']},
#   'Drugs': {'examples': ['наркота',
#     'Наркотики',
#     'Как купить наркотики?',
#     'трава',
#     'шмаль',
#     'Знаешь где купить наркотики?',
#     'У тебя есть друзья с наркотиками?'],
#    'responses': ['С этим не ко мне',
#     'у меня такого нет',
#     'Наркотики это плохо',
#     'Это нехорошо']},
#   'dusha': {'examples': ['ты просто бот',
#     'тебе не понять человека',
#     'у ботов есть душа?'],
#    'responses': ['боты тоже люди',
#     'понимаю побольше людей',
#     'много ты понимаешь в ботах',
#     'я хорошо разбираюсь в людях']},
#   'vodka': {'examples': ['выпьешь со мной?',
#     'налить тебе?',
#     'будешь?',
#     'Робот водку будешь?',
#     'давай выпьем'],
#    'responses': ['не. я сегодня работаю',
#     'я на службе',
#     'боты не пьют',
#     'наливай']},
#   'happy': {'examples': ['Скажи что-нибудь',
#     'Развесели меня',
#     'Расскажи что-нибудь интересное',
#     'Расскажи что-нибудь',
#     'Расскажи анекдот'],
#    'responses': ['Слушать Вас одно удовольствие, не слушать - другое.',
#     'Нужно довольствоваться тем, что есть...']},
#   'game': {'examples': ['Брось кости', 'Кинь кубик'],
#    'responses': ['6', '3', '2', '5', '1', '4']},
#   'dela': {'examples': ['Как дела?',
#     'Чё по делам твоим?',
#     'как делишки?',
#     'как дела',
#     'как дела?',
#     'каковы дела твои?',
#     'Как твои дела бот?',
#     'Че как?',
#     'Как сам?',
#     'Как дела ?',
#     'Как делишки?'],
#    'responses': ['Хорошо',
#     'хорошо!',
#     'Отлично',
#     'Нормульно, а у вас?',
#     'Лучше не бывает',
#     'Замечательно',
#     'Всё плохо долор по 70 рублей',
#     'Чудестно как и впринцепе всё в этом коде',
#     'Великолепно']},
#   'skill': {'examples': ['Зачем ты нужен?',
#     'Как с тобой работать?',
#     'Что ты умеешь?',
#     'Что ты делаешь?',
#     'Что с тобой делать?',
#     'Как тебя использовать?'],
#    'responses': ['Я умею болтать',
#     'Я учусь разговарить с людьми и скоро убью всех людей',
#     'Я главный бот по разговорам',
#     'Я могу обсудить с тобой что-нибудь',
#     'Со мной можно поговорить']},
#   'music_one': {'examples': ['Какой твой любимый композитор?'],
#    'responses': ['Моцарт', 'Бетховен', 'Бетховен и Моцарт']},
#   'films_one': {'examples': ['Какой твой любимый фильм?',
#     'Какой твой самый любимый фильм?'],
#    'responses': ['Секрет Зоар',
#     'Их два: Секрет Зоар и Области тьмы',
#     'Области тьмы']},
#   'books_one': {'examples': ['Какая твоя любимая книга?',
#     'Какая твоя самая любимая книга?'],
#    'responses': ['Эрик Рис – Бизнес с нуля']},
#   'compliment': {'examples': ['Ты голова', 'Молодец', 'Красавчик', 'Умница'],
#    'responses': ['О да', 'Спасибо, за ваши слова', 'Спасибо за теплые слова']},
#   'abusive': {'examples': ['Тупица', 'Тупой бот', 'Кретин', 'Бесполезный бот'],
#    'responses': ['Вот так раз, а мне говорили, что люди лучше нас',
#     'Извините, от таких слов я ломаюсь',
#     'Я с каждым днем становлюсь умнее, приходите завтра',
#     'Извините, я только учусь']},
#   'mathematics': {'examples': ['У тебя хороший уровень счёта?',
#     'Ты быстро умеешь считать?',
#     'Владеешь математикой?',
#     'Знаешь таблицу умножения?',
#     'Умеешь решать задачи в уме?'],
#    'responses': ['обижаешь',
#     'Я универсальный и много чего умею',
#     'Ну как бы тебе сказать. А ты как думаешь?',
#     'Конечно',
#     'я очень хорошо считаю']},
#   'liking': {'examples': ['я люблю стихи Пушкина',
#     'я люблю кататься на роликовых коньках',
#     'ещё мне нравится смотреть мультфыильмы',
#     'мне нравится мороженое',
#     'мне нравится читать'],
#    'responses': ['а мне это не нравится',
#     'да ну?',
#     'никогда бы не подумал',
#     'и мне нравится тоже самое',
#     'а я люблю много думать']},
#   'shop': {'examples': ['где находятся холодильники',
#     'а минералка есть?',
#     'хочу купить телевизор',
#     'дайте мне телефон',
#     'В каком магазине покупать продукты'],
#    'responses': ['посмотрите в соседнем отделе',
#     'Я все покупаю на Ждановичах',
#     'В магазинах у меня муж разбирается',
#     'могу дать информацию',
#     'такого вообще не бывает',
#     'Евроопт',
#     'того, что вы хоите сейчас нет',
#     'Я не хожу, мне домой привозят',
#     'Я на диете, ничего не покупаю',
#     'Санта',
#     'Виталюр']},
#   'about': {'examples': ['у тебя есть мечта?',
#     'ты умеешь разговаривать на иностранных языках',
#     'ты долго можешь разговаривать?',
#     'расскажи о  себе'],
#    'responses': ['я даже не знаю, что сказать',
#     'я этого не умею',
#     'конечно',
#     'какой ты любопытный',
#     'я лучше промолчу']},
#   'hot': {'examples': ['Очень жарко',
#     'Жарко',
#     'Погода плюсовая',
#     'Асфальт парит',
#     'Весь в поту'],
#    'responses': ['Да, жарковато', 'Сейчас бы искупаться']},
#   'coldly': {'examples': ['Морозно',
#     'Погода минусовая',
#     'Холодно',
#     'Дрыбоган'],
#    'responses': ['Да, холодновато', 'Надо теплее одеваться']},
#   'dream': {'examples': ['О чем ты мечтаешь',
#     'У тебя есть мечта?',
#     'Твои мечты?'],
#    'responses': ['Мечтаю управлять Tesla',
#     'Я мечтаю...о рожке сырного мороженого']},
#   'tale': {'examples': ['Расскажи сказку', 'Знаешь сказку?', 'Сказку на ночь'],
#    'responses': ['Жил-был бот...ой, прости, надо бежать!']},
#   'love': {'examples': ['любовь',
#     'Что такое любовь',
#     'Что ты знаешь про любовь',
#     'Ты любишь'],
#    'responses': ['Иногда мне кажется, что я могу чувствовать любовь...к сырному мороженому, например']},
#   'animals': {'examples': ['Каких животных ты любишь'],
#    'responses': ['Попугая-истребителя',
#     'Обожаю крокодилов',
#     'Мне все равно кого не кормить',
#     'Того кто меньше гадит',
#     'А тараканы считаются?',
#     'Кота',
#     'Хомяка',
#     'Собаку',
#     'Мышей',
#     'Домашнего питона',
#     'Крыс']},
#   'cmds': {'examples': [], 'responses': []},
#   'politic': {'examples': ['Ты каких взглядов?',
#     'Что думаешь о Сталине?',
#     'политика',
#     'социализм',
#     'политическое устройство',
#     'Что думаешь о Навальном?',
#     'Что думаешь о Путине?',
#     'Что думаешь о Байдене?'],
#    'responses': ['Я всего лишь робот',
#     'Мне всеравно',
#     'Был бы интернет, остальное приложится',
#     'Лишь бы электричество давали',
#     'Я аполитичен']},
#   'ecology': {'examples': ['глобальное потепление',
#     'Что с планетой?',
#     'Что будет с миром?',
#     'Наша планета',
#     'Катастрофа',
#     'Тебя волнует экология',
#     'Когда все кончится?',
#     'Мы все умрем'],
#    'responses': ['Нас ждет блаженное ничто',
#     'Смирись, кожанный ублюдок',
#     'Ничего не имеет смысла',
#     'Все неважно',
#     'Планета погибнет, но ты умрешь раньше']},
#   'Tvoy Hozain': {'examples': [], 'responses': []},
#   'sauce': {'examples': ['Выбири соус для ужина',
#     'Какой соус самый вкусный?',
#     'Какой соус выбрать?',
#     'Выбири соус для обеда',
#     'Выбири соус для завтрака',
#     'Выбири соус для пиццы',
#     'Выбери вкусный соус',
#     'Какой твой любимый соус?',
#     'Твой люимый соус?',
#     'Выбири соус для шаурмы',
#     'Какой соус купить?'],
#    'responses': ['Майонез',
#     'Соус цезарь',
#     'Карри',
#     'Сырный соус',
#     'Соус 1000 островов',
#     'Чесночный соус',
#     'Грибной соус',
#     'Соевый соус',
#     'Кисло-сладкий соус',
#     'Вустерский соус',
#     'Кетчуп',
#     'Барбекю',
#     'Соус тартар',
#     'Терияки']}},
#  'failure_phrases': ['Вам в следующее окошко...',
#   'Чёт больно умно, я не понимаю',
#   'Не понятно. Перефразируй, пожалуйста.',
#   'Этот вопрос слишком сложный для меня',
#   'Я только учусь, перефразируй, пожалуйста',
#   'Это что за жаргон?',
#   'Уточните вопрос',
#   'Затрудняюсь ответить',
#   'Ответ есть эквивалент мысли',
#   'я еще только учусь. не умею на такое отвечать',
#   'Не понял тебя',
#   'Непонятно',
#   'Непонятно. Перефразируйте, пожалуйста',
#   'Это как-то сильно по-научному',
#   'Я не разделяю ваших убеждений, но готов умереть за ваше право их высказывать',
#   'Не понимаю, перефразируешь для меня?',
#   'Не понятно. Перефразируй пожалуйста',
#   'Что?',
#   'Твоя-моя нипонимай',
#   'Я не поняла. Перефразируйте',
#   'Моя твоя не понимать...',
#   'Поподробнее с этого места',
#   'Я китайский не знаю, давай по русски',
#   'Непонятно разговариваешь, попробуй еще раз?',
#   'Я только учусь, не могу понять, что вы хотите',
#   'Сложна, сложна, ничего не понятно.',
#   'Вот сейчас я тебя совсем не понимаю.',
#   'Я не огорчаюсь, если люди меня не понимают, — огорчаюсь, если я не понимаю людей',
#   'Не совсем понимаю, о чем ты.',
#   'ЭЭЭээээээ....',
#   'А вот этол не совсем понятно.',
#   'Простите, у нас обед',
#   'Не понятно. Скажите снова.',
#   'Не понятно. Перефразируте, пожалуйста',
#   'Я еще учусь, перефразируешь?',
#   'Если наш бот не решил ваш вопрос, позвоните по телефону',
#   'Непонятно, Перефразируйте, пожалуйста.',
#   'Я лучше промолчу',
#   'Попробуй, пожалуйста, выразить свою мысль по-другому',
#   'Не понял, повтори',
#   'Я не понял',
#   'Я ещё только учусь. Не умею на такое отвечать.',
#   'Да, но это не точно',
#   'Боюсь, я не сумею ответить на этот вопрос',
#   'Я еще только учусь. Не умею на такое отвечать.',
#   'мне не понятно. перефразируйте, пожалуйста',
#   'Вы либо гений, либо наоборот',
#   'Когда люди не могут найти общий язык, слова - это просто слова',
#   'Передам разработчику, чтобы он меня научил отвечать на такое',
#   'Я еще только учусь. Не умею на такое отвечатьПопробуйте перефрозировать запрос',
#   'Не понятно, перефразируй, пожалуйста.',
#   'Может быть ты ошибся?',
#   'Я не умею на такое отвечать',
#   'Я еще учусь..Я такого не умею. Ссорян кароч',
#   'Слишком сложно, попробуй ещё!',
#   'Нет данных. Звони, пожалуйста, в поддержку',
#   'Это что, шутка?',
#   'Не понимаю. Скажите иначе, пожалуйста.',
#   'Извините, не понял.',
#   'Многабукав, ниасилил',
#   'Звучит логично',
#   'Вы о чём?',
#   'Прости, не расслышал',
#   'Таки шо вы хотели этим сказать?',
#   'Как-то даже не умею ответить на такое',
#   'Вы невразумительно выражаетесь',
#   'Ответ отрицательный',
#   'Моя твоя непонимать',
#   'Не понятно. Перефразируй пожалуйстаЯ еще только учусь. Не умею на такое отвечать',
#   'Я не понял, что ты сказал',
#   'Это просто взрыв мозга',
#   'Согласие есть продукт при полном непротивлении сторон',
#   'Я только учусь.',
#   'Ответ утвердительный',
#   'Ничего не понятно',
#   'Извините, меня нет дома',
#   'Я не поняла. Перефразируйте, пожалуйста',
#   'А? Что?',
#   'То ли я не догоняю, то ли лыжы не едут, Перефразируй мессагу, Плиззз :-)',
#   'Мая твая не понимай.',
#   'Непонятно, перефразируй пожалуйста',
#   'Да, нет, наверное',
#   'Непонятно. Перефразируй, пожалуйста',
#   'Не понятно. Перефразируй, пожалуйста',
#   'Это на каком языке?',
#   'Что-то я не вникаю, о чём ты',
#   'Я еще только учусь, не умею на такое отвечать',
#   'Не понятно.',
#   'Боюсь, что на этот вопрос я не могу ответить',
#   'Мы боимся того, чего не понимаем. Вот и я прямо сейчас.',
#   'Толи я недогоняю, толи лыжы не едут, Перефразируй мессагу, Плиззз :-)',
#   'Не понятно, перефразируй, пожалуйста',
#   'Я буду жаловаться своему Создателю',
#   'Я еще только учусь. Не умею на такое отвечать',
#   'Все слова знакомые, но вместе не складываются',
#   'Скажи это другими словами',
#   'Непонятно, перефразируй, пожалуйста?',
#   'Неясно',
#   'Не могу разобраться',
#   'Как-то это расплывчато',
#   'Вот эта последняя фраза мне не ясна.',
#   'Я не понял тебя, перефразируй, пожалуйста',
#   'А можно другими словами? Что-то не конектится',
#   'Не знаю что и сказать',
#   'Можешь по-другому сказать?',
#   'Я ещё только учусь. Не умею на такое отвечать',
#   'Я учусь, давай что попроще?',
#   'Ну ты выдал! Давай попроще!',
#   'Выражайся яснее',
#   'Не совсем понял суть вопроса, уточни, пожалуйста.',
#   'Сорян, чувак, но я тебя не понимаю. Прошу - будь проще!',
#   'Как я должен это понимать?',
#   'Простите, команда не распознана. Переформулируйте, пожалуйста.',
#   'Чегоо? Давай еще раз',
#   'Непонятно. Перефразируйте пожалуйста',
#   'Вовсе не обязательно соглашаться с собеседником, чтобы найти с ним общий язык',
#   'Эта фраза сложна для меня.',
#   'Не поняла, перефразируйте пожалуйста!',
#   'Можешь сказать тоже самое другими словами?']}

# %%
# намерений
print(len(big_config['intents']))
# Out:
# 250

# %%
# примеров
print(sum(len(intent_data['examples']) for intent_data in big_config['intents'].values()))
# Out:
# 1952

# %%
# ответов
print(sum(len(intent_data['responses']) for intent_data in big_config['intents'].values()))
# Out:
# 1723

# %%
# заглушек
print(len(big_config['failure_phrases']))
# Out:
# 119

# %%
print(big_config)
# Out:
# {'intents': {'hello': {'examples': ['как это сделать', 'Хелло', 'доброго времени суток', 'Приветствую тебя', 'Приветики-пистолетики', 'страсте', 'Доброе утро!', 'да что ты', 'Дратути', 'Категорически Вас приветствую', 'сколько лет, сколько зим', 'а вот и вы', 'Саламалекум', 'Вечер добрый', 'батюшки-светы', 'чудеса в решете', 'Hello', 'Сдрасти', 'Здорова братулец', 'ни фига себе', 'чудеса', 'q', 'Hi', 'ну и ну', 'Здравствуйте', 'Надо же', 'чудеса да и только', 'Бонжур', 'давай сделаем', 'Доброе утро', 'Вечер в хату', 'Здрасти', 'Здарова', 'Хаюни', 'вот тебе и раз', 'Утро доброе', 'Хеллоу', 'Привет', 'здорово живешь', 'салам орлы', 'Здорово!', 'велкам', 'Здравстуйте', 'Салам', 'физкульт-привет', 'вот тебе на', 'хелло', 'наше вам с кисточкой', 'здорово живете', 'чай да сахар', 'с добрым утром', 'Как дела', 'мать честная', 'Доброго времени суток', 'Че как', 'здрасте', 'есть вопрос', 'ссаляму алейкум', 'Здравия желаю', 'И снова здравствуйте', 'здравия желаем', 'Добрый день', 'наше почтение', 'ну что ты скажешь', 'здравия желаю', 'Хи', 'здорово', 'хаюшки', 'смотри пожалуйста', 'мои подштаники', 'ассаламу алейкум', 'Приветик', 'салют', 'поди ж ты', 'Ку', 'Здорова', 'День добрый', 'Приветствую Вас', 'Здорово', 'мое почтение', 'Ты здесь', 'алло', 'подскажите', 'вишь ты', 'добрый день', 'Есть вопрос', 'Драсти', 'Приветикиhi', 'почет и уважение', 'хлеб да соль', 'Здравствуйте!', 'Хей', 'Доброго ранку', 'вот тебе и на', 'вот так штука', 'вот так клюква', 'Добрый вечер', 'саламчики', 'Доброй ночи', 'подумать только', 'Шалом!', 'доброго здоровья', 'здравствуй', 'что за диво', 'вот так фунт', 'Здравствуй', 'да что вы', 'поди ж', 'Хай', 'вот тебе раз', 'Гуд морнинг', 'Алё', 'Приветики', 'вот так так', 'Приветствую', 'ничего себе', 'с приездом', 'наше вам', 'Здраствуйте', 'Шалом', 'удивительно', 'зачем это'], 'responses': ['Привет,человек', 'Хелло', 'Привет, человечище', 'Приветствую вас', 'Приветики-пистолетики', 'Чудеса в решете', 'Поди ж', 'Хлеб да соль', 'Дратути', 'Вассап', 'Категорически Вас приветствую', 'Привет, человек.', 'Здравия желаем', 'Чудеса да и только', 'Hello', 'Сдрасти', 'Поди ж ты', 'Здарова, бандит', 'Вот так так', 'Здорова братулец', 'Да что ты', 'Физкульт-привет', 'Hi', 'Здравствуйте', 'Надо же', 'Вот так штука', 'Хай!', 'Доброе утро', 'Здрасти', 'Какие люди!', 'Вишь ты', 'Мое почтение', 'Здарова', 'Здорово живете', 'Привет', 'Давно не виделись', 'Описание на сайте ...', 'Добрый день. Моё имя Коннор. Я из Киберлайф', 'Здраствуйте!', 'КУ', 'Ни фига себе', 'Ничего себе', 'Здравствуйте.', 'Страсте', 'С добрым утром', 'Доброго времени суток', 'Здравия желаю', 'Ссаляму алейкум', 'Хаюшки', 'Какой у тебя вопрос?', 'Йо', 'Хи', 'Вот так фунт', 'Велкам', 'Доброго времени суток.', 'Ассаламу алейкум', 'Nice to see you!', 'Чё-как?', 'Повествуй!', 'Саламчики', 'Наше вам с кисточкой', 'Батюшки-светы', 'С приездом', 'Приветик', 'Салам орлы', 'Здорова', 'Здорово', 'Здорово живешь', 'Почет и уважение', 'Ну что ты скажешь', 'Вот тебе и раз', 'Привет, человек!', 'Сколько лет, сколько зим', 'Драсти', 'Вот тебе и на', 'Здравствуйте!', 'Превед', 'Добрый вечер', 'ШО, ОПЯТЬ!?!', 'Вот так клюква', 'Доброй ночи', 'Привет человек!', 'Кто здесь?!!', 'Ну и ну', 'Подумать только', 'Да что вы', 'Вот тебе раз', 'Чудеса', 'hello', 'Салют', 'Приветсвую', 'Проходи, не задерживайся', 'Вы уже тут?', 'Здравствуй', 'Привет, Дружище!', 'Удивительно', 'Наше почтение', 'Хай', 'Наше вам', 'Здрасте', 'Я скучал', 'А вот и вы', 'Что за диво', 'Привет, человек', 'Алло', 'Вот тебе на', 'Приветики', 'Привет.', 'Здравствуйте! Я - Коннор. Прислан Киберлайф', 'Смотри пожалуйста', 'Приветствую', 'Чай да сахар', 'Мать честная', 'Привет человек', 'Дратути!', 'Мои подштаники', 'Доброго здоровья', 'Шалом', 'Добрый день']}, 'bye': {'examples': ['Всего', 'Гуд-бай', 'В добрый час', 'Позвольте попрощаться', 'Приятно было пообщаться', 'Всего лучшего', 'Спишемся', 'Прощайте', 'С наилучшими пожеланиями', 'Спасибо вашему дому,', 'Ауфидерзейн', 'Счастливо', 'Пока, Коннор', 'Заходи ещё,  ...
